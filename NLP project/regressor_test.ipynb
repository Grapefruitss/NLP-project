# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.model_selection import train_test_split
from sklearn.metrics import root_mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
import csv
import random
import optuna

# %%
# 셀에서 출력 정확도 설정.
# %precision %.3f
# Out:
# '%.3f'

# %%
file_path = r'.\crawling_data\preprocessed_essay.csv'

# 자소서 리스트화
documents = []
with open(file_path, 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        documents.append(row[0])
        
# documents_5 = documents[:22]
# documents_4 = documents[22:77]
# documents_3 = documents[77:175]
# documents_2 = documents[175:302]
# documents_1 = documents[302:]

# documents = random.sample(documents_5, 15) + random.sample(documents_4, 15) + random.sample(documents_3, 15) + random.sample(documents_2, 15) + documents_1

# %%
# 전문가 평점 1~5점 각 15개씩 랜덤으로 가져와서 점수 라벨링
# 회귀 예측용 label
labels = []
for i in range(317):
    if i < 22:
        labels.append(5)
    elif i < 77:
        labels.append(4)
    elif i < 175:
        labels.append(3)
    elif i < 302:
        labels.append(2)        
    else:
        labels.append(1)

# %%
# 불용어 리스트 가져오기
stop_words = set(stopwords.words('english'))

def preprocess(text):
    tokens = word_tokenize(text)
    filtered_tokens = [word for word in tokens if word.isalpha() and word not in stop_words]
    return filtered_tokens

documents_corpus = []
for document in documents:
    documents_corpus.append(preprocess(document))

# %%
# Tagged Corpus 생성.
# 모델 학습에 필요한 형태로 변환.
my_tagged_corpus = [TaggedDocument(words=my_words, tags=[i]) for i, my_words in enumerate(documents_corpus)]

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

def objective(trial):
    # 하이퍼파라미터 샘플링
    vector_size = trial.suggest_int('vector_size', 20, 100)
    window = trial.suggest_int('window', 2, 10)
    min_count = trial.suggest_int('min_count', 1, 5)
    epochs = trial.suggest_int('epochs', 10, 50)

    # Doc2Vec 모델 생성 및 학습
    model = Doc2Vec(vector_size=vector_size, window=window, min_count=min_count, epochs=epochs)
    model.build_vocab(my_tagged_corpus)
    model.train(my_tagged_corpus, total_examples=model.corpus_count, epochs=model.epochs)

# 레이블별로 코사인 유사도 평가
    label_1_vectors = [model.dv[i] for i, label in enumerate(labels) if label == 1]
    label_2_vectors = [model.dv[i] for i, label in enumerate(labels) if label == 2]
    label_3_vectors = [model.dv[i] for i, label in enumerate(labels) if label == 3]
    label_4_vectors = [model.dv[i] for i, label in enumerate(labels) if label == 4]
    label_5_vectors = [model.dv[i] for i, label in enumerate(labels) if label == 5]

    # 레이블 1 문서들 간의 유사도 평균
    similarity_scores_1 = []
    for i in range(len(label_1_vectors)):
        for j in range(i + 1, len(label_1_vectors)):
            similarity_scores_1.append(cosine_similarity([label_1_vectors[i]], [label_1_vectors[j]])[0][0])
    mean_similarity_1 = np.mean(similarity_scores_1) if similarity_scores_1 else 0

    # 레이블 2 문서들 간의 유사도 평균
    similarity_scores_2 = []
    for i in range(len(label_2_vectors)):
        for j in range(i + 1, len(label_2_vectors)):
            similarity_scores_2.append(cosine_similarity([label_2_vectors[i]], [label_2_vectors[j]])[0][0])
    mean_similarity_2 = np.mean(similarity_scores_2) if similarity_scores_2 else 0

    # 레이블 2 문서들 간의 유사도 평균
    similarity_scores_3 = []
    for i in range(len(label_3_vectors)):
        for j in range(i + 1, len(label_3_vectors)):
            similarity_scores_3.append(cosine_similarity([label_3_vectors[i]], [label_3_vectors[j]])[0][0])
    mean_similarity_3 = np.mean(similarity_scores_3) if similarity_scores_3 else 0

        # 레이블 2 문서들 간의 유사도 평균
    similarity_scores_4 = []
    for i in range(len(label_4_vectors)):
        for j in range(i + 1, len(label_4_vectors)):
            similarity_scores_4.append(cosine_similarity([label_4_vectors[i]], [label_4_vectors[j]])[0][0])
    mean_similarity_4 = np.mean(similarity_scores_4) if similarity_scores_4 else 0

        # 레이블 2 문서들 간의 유사도 평균
    similarity_scores_5 = []
    for i in range(len(label_5_vectors)):
        for j in range(i + 1, len(label_5_vectors)):
            similarity_scores_5.append(cosine_similarity([label_5_vectors[i]], [label_5_vectors[j]])[0][0])
    mean_similarity_5 = np.mean(similarity_scores_5) if similarity_scores_5 else 0

    # 두 유사도의 평균을 최종 점수로 사용
    final_similarity_score = (mean_similarity_1 + mean_similarity_2 + mean_similarity_3 + mean_similarity_4 + mean_similarity_5) / 5
    
    return final_similarity_score

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100, n_jobs=-1)

print(f'Best parameters: {study.best_params}')
print(f'Best similarity score: {study.best_value}')
# Out:
# [I 2024-06-27 21:44:57,432] A new study created in memory with name: no-name-6f87696f-86a2-4986-8698-73a6ede4b4f9
# [I 2024-06-27 21:45:21,585] Trial 6 finished with value: 0.6756621360778808 and parameters: {'vector_size': 43, 'window': 7, 'min_count': 3, 'epochs': 11}. Best is trial 6 with value: 0.6756621360778808.
# [I 2024-06-27 21:45:27,083] Trial 1 finished with value: 0.39259097576141355 and parameters: {'vector_size': 29, 'window': 4, 'min_count': 3, 'epochs': 22}. Best is trial 6 with value: 0.6756621360778808.
# [I 2024-06-27 21:45:46,268] Trial 4 finished with value: 0.32061400413513186 and parameters: {'vector_size': 42, 'window': 4, 'min_count': 2, 'epochs': 29}. Best is trial 6 with value: 0.6756621360778808.
# [I 2024-06-27 21:45:51,124] Trial 5 finished with value: 0.41011853218078614 and parameters: {'vector_size': 45, 'window': 10, 'min_count': 3, 'epochs': 18}. Best is trial 6 with value: 0.6756621360778808.
# [I 2024-06-27 21:45:55,631] Trial 7 finished with value: 0.4002655029296875 and parameters: {'vector_size': 84, 'window': 9, 'min_count': 4, 'epochs': 18}. Best is trial 6 with value: 0.6756621360778808.
# [I 2024-06-27 21:46:12,194] Trial 3 finished with value: 0.2507232666015625 and parameters: {'vector_size': 49, 'window': 4, 'min_count': 3, 'epochs': 46}. Best is trial 6 with value: 0.6756621360778808.
# [I 2024-06-27 21:46:19,835] Trial 10 finished with value: 0.7698801040649415 and parameters: {'vector_size': 90, 'window': 8, 'min_count': 2, 'epochs': 10}. Best is trial 10 with value: 0.7698801040649415.
# [I 2024-06-27 21:46:21,488] Trial 2 finished with value: 0.26937341690063477 and parameters: {'vector_size': 98, 'window': 3, 'min_count': 4, 'epochs': 30}. Best is trial 10 with value: 0.7698801040649415.

# %%
best_params = study.best_params

best_vector_size = best_params['vector_size']
best_window = best_params['window']
best_min_count = best_params['min_count']
best_epochs = best_params['epochs']

best_d2vmodel = Doc2Vec(vector_size=best_vector_size, window=best_window, min_count=best_min_count, epochs=best_epochs)
best_d2vmodel.build_vocab(my_tagged_corpus)
best_d2vmodel.train(my_tagged_corpus, total_examples=best_d2vmodel.corpus_count, epochs=best_d2vmodel.epochs)

import pickle

with open('d2v_model_rg.pkl', 'wb') as f:
    pickle.dump(best_d2vmodel, f)

# %%
# from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import r2_score

# # 데이터 준비
# X = [best_d2vmodel.dv[i] for i in range(len(documents_corpus))]
# y = labels  # 레이블이 회귀 타겟 값이라고 가정

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# def objective(trial):
#     # 모델 선택
#     regressor_name = trial.suggest_categorical('regressor', ['LinearRegression', 'SVR', 'RandomForest', 'XGBoost', 'LightGBM'])
    
#     if regressor_name == 'LinearRegression':
#         model = LinearRegression()

#     elif regressor_name == 'SVR':
#         svr_c = trial.suggest_float('svr_c', 1e-3, 1e3, log=True)
#         svr_epsilon = trial.suggest_float('svr_epsilon', 1e-3, 1.0, log=True)
#         svr_kernel = trial.suggest_categorical('svr_kernel', ['linear', 'poly', 'rbf', 'sigmoid'])
#         model = SVR(C=svr_c, epsilon=svr_epsilon, kernel=svr_kernel)

#     elif regressor_name == 'RandomForest':
#         rf_n_estimators = trial.suggest_int('rf_n_estimators', 50, 500)
#         rf_max_depth = trial.suggest_int('rf_max_depth', 2, 32)
#         rf_min_samples_split = trial.suggest_int('rf_min_samples_split', 2, 10)
#         rf_min_samples_leaf = trial.suggest_int('rf_min_samples_leaf', 1, 4)
#         rf_max_features = trial.suggest_categorical('rf_max_features', ['sqrt', 'log2'])
#         model = RandomForestRegressor(n_estimators=rf_n_estimators, max_depth=rf_max_depth,
#                                       min_samples_split=rf_min_samples_split, min_samples_leaf=rf_min_samples_leaf,
#                                       max_features=rf_max_features, random_state=42)

#     elif regressor_name == 'XGBoost':
#         xgb_n_estimators = trial.suggest_int('xgb_n_estimators', 50, 500)
#         xgb_max_depth = trial.suggest_int('xgb_max_depth', 2, 32)
#         xgb_learning_rate = trial.suggest_float('xgb_learning_rate', 0.01, 0.3, log=True)
#         xgb_subsample = trial.suggest_float('xgb_subsample', 0.5, 1.0)
#         xgb_colsample_bytree = trial.suggest_float('xgb_colsample_bytree', 0.5, 1.0)
#         xgb_gamma = trial.suggest_float('xgb_gamma', 0, 5)
#         model = XGBRegressor(n_estimators=xgb_n_estimators, max_depth=xgb_max_depth, learning_rate=xgb_learning_rate,
#                              subsample=xgb_subsample, colsample_bytree=xgb_colsample_bytree, gamma=xgb_gamma, random_state=42)

#     elif regressor_name == 'LightGBM':
#         lgb_n_estimators = trial.suggest_int('lgb_n_estimators', 50, 500)
#         lgb_max_depth = trial.suggest_int('lgb_max_depth', 2, 32)
#         lgb_learning_rate = trial.suggest_float('lgb_learning_rate', 0.01, 0.3, log=True)
#         lgb_num_leaves = trial.suggest_int('lgb_num_leaves', 20, 150)
#         lgb_min_child_samples = trial.suggest_int('lgb_min_child_samples', 5, 100)
#         lgb_subsample = trial.suggest_float('lgb_subsample', 0.5, 1.0)
#         lgb_colsample_bytree = trial.suggest_float('lgb_colsample_bytree', 0.5, 1.0)
#         model = LGBMRegressor(n_estimators=lgb_n_estimators, max_depth=lgb_max_depth, learning_rate=lgb_learning_rate,
#                               num_leaves=lgb_num_leaves, min_child_samples=lgb_min_child_samples,
#                               subsample=lgb_subsample, colsample_bytree=lgb_colsample_bytree, random_state=42)

#     # 교차 검증으로 모델 평가
#     score = cross_val_score(model, X_train, y_train, cv=5, scoring='r2')
#     r2 = score.mean()
#     return r2

# # Optuna 최적화
# study = optuna.create_study(direction='maximize')
# study.optimize(objective, n_trials=1000, n_jobs=-1)

# # 최적의 하이퍼파라미터로 모델 학습
# best_params = study.best_params
# regressor_name = best_params.pop('regressor')

# if regressor_name == 'LinearRegression':
#     model = LinearRegression()

# elif regressor_name == 'SVR':
#     model = SVR(C=best_params['svr_c'], epsilon=best_params['svr_epsilon'], kernel=best_params['svr_kernel'])

# elif regressor_name == 'RandomForest':
#     model = RandomForestRegressor(n_estimators=best_params['rf_n_estimators'], max_depth=best_params['rf_max_depth'],
#                                   min_samples_split=best_params['rf_min_samples_split'], min_samples_leaf=best_params['rf_min_samples_leaf'],
#                                   max_features=best_params['rf_max_features'], random_state=42)

# elif regressor_name == 'XGBoost':
#     model = XGBRegressor(n_estimators=best_params['xgb_n_estimators'], max_depth=best_params['xgb_max_depth'], learning_rate=best_params['xgb_learning_rate'],
#                          subsample=best_params['xgb_subsample'], colsample_bytree=best_params['xgb_colsample_bytree'], gamma=best_params['xgb_gamma'], random_state=42)

# elif regressor_name == 'LightGBM':
#     model = LGBMRegressor(n_estimators=best_params['lgb_n_estimators'], max_depth=best_params['lgb_max_depth'], learning_rate=best_params['lgb_learning_rate'])

# model.fit(X_train, y_train)
# y_pred = model.predict(X_test)
# r2 = r2_score(y_test, y_pred)

# print(f'Best model: {regressor_name}')
# print(f'Best parameters: {best_params}')
# print(f'Test R2: {r2}')
# Out:
# [I 2024-06-27 21:35:23,590] A new study created in memory with name: no-name-ef1d3993-7dea-4084-b5eb-047c39bfe219
# [I 2024-06-27 21:35:23,756] Trial 3 finished with value: -0.8069068825379482 and parameters: {'regressor': 'LinearRegression'}. Best is trial 3 with value: -0.8069068825379482.
# [I 2024-06-27 21:35:23,772] Trial 2 finished with value: 0.1046299394068239 and parameters: {'regressor': 'SVR', 'svr_c': 45.36127953443427, 'svr_epsilon': 0.43265978720338516, 'svr_kernel': 'linear'}. Best is trial 2 with value: 0.1046299394068239.
# [I 2024-06-27 21:35:23,798] Trial 5 finished with value: -0.8069068825379482 and parameters: {'regressor': 'LinearRegression'}. Best is trial 2 with value: 0.1046299394068239.
# [I 2024-06-27 21:35:23,855] Trial 8 finished with value: -0.8069068825379482 and parameters: {'regressor': 'LinearRegression'}. Best is trial 2 with value: 0.1046299394068239.
# [I 2024-06-27 21:35:25,643] Trial 1 finished with value: -0.0757878448674874 and parameters: {'regressor': 'RandomForest', 'rf_n_estimators': 132, 'rf_max_depth': 24, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt'}. Best is trial 2 with value: 0.1046299394068239.
# [I 2024-06-27 21:35:25,961] Trial 4 finished with value: -0.06713700864751648 and parameters: {'regressor': 'LightGBM', 'lgb_n_estimators': 261, 'lgb_max_depth': 6, 'lgb_learning_rate': 0.02389802906863003, 'lgb_num_leaves': 146, 'lgb_min_child_samples': 33, 'lgb_subsample': 0.7443291224223512, 'lgb_colsample_bytree': 0.6573029779699118}. Best is trial 2 with value: 0.1046299394068239.
# [I 2024-06-27 21:35:27,162] Trial 0 finished with value: -0.14702470889801 and parameters: {'regressor': 'XGBoost', 'xgb_n_estimators': 255, 'xgb_max_depth': 21, 'xgb_learning_rate': 0.09681135994086545, 'xgb_subsample': 0.6398142032517896, 'xgb_colsample_bytree': 0.547366432803939, 'xgb_gamma': 3.00968719047908}. Best is trial 2 with value: 0.1046299394068239.
# [I 2024-06-27 21:35:27,330] Trial 14 finished with value: -0.8069068825379482 and parameters: {'regressor': 'LinearRegression'}. Best is trial 2 with value: 0.1046299394068239.
# [I 2024-06-27 21:35:27,468] Trial 7 finished with value: -0.06713700864751648 and parameters: {'regressor': 'LightGBM', 'lgb_n_estimators': 449, 'lgb_max_depth': 14, 'lgb_learning_rate': 0.015252083919802989, 'lgb_num_leaves': 89, 'lgb_min_child_samples': 43, 'lgb_subsample': 0.7167179832270592, 'lgb_colsample_bytree': 0.8228789941075153}. Best is trial 2 with value: 0.1046299394068239.
# [I 2024-06-27 21:35:27,505] Trial 15 finished with value: -0.8069068825379482 and parameters: {'regressor': 'LinearRegression'}. Best is trial 2 with value: 0.1046299394068239.
# [I 2024-06-27 21:35:27,628] Trial 16 finished with value: -0.8069068825379482 and parameters: {'regressor': 'LinearRegression'}. Best is trial 2 with value: 0.1046299394068239.
# [I 2024-06-27 21:35:27,720] Trial 17 finished with value: 0.07866346882158784 and parameters: {'regressor': 'SVR', 'svr_c': 70.05873335446702, 'svr_epsilon': 0.7470780529408912, 'svr_kernel': 'linear'}. Best is trial 2 with value: 0.1046299394068239.
# [I 2024-06-27 21:35:27,814] Trial 9 finished with value: -0.06713700864751648 and parameters: {'regressor': 'LightGBM', 'lgb_n_estimators': 475, 'lgb_max_depth': 6, 'lgb_learning_rate': 0.017165497360576005, 'lgb_num_leaves': 51, 'lgb_min_child_samples': 82, 'lgb_subsample': 0.5805697834187834, 'lgb_colsample_bytree': 0.5254627025947268}. Best is trial 2 with value: 0.1046299394068239.
# [I 2024-06-27 21:35:27,817] Trial 18 finished with value: 0.052299239270417776 and parameters: {'regressor': 'SVR', 'svr_c': 98.13933349912018, 'svr_epsilon': 0.7205210777050983, 'svr_kernel': 'linear'}. Best is trial 2 with value: 0.1046299394068239.
# [I 2024-06-27 21:35:28,021] Trial 19 finished with value: 0.08662436259175876 and parameters: {'regressor': 'SVR', 'svr_c': 48.430613453512635, 'svr_epsilon': 0.863586451490225, 'svr_kernel': 'linear'}. Best is trial 2 with value: 0.1046299394068239.
# [I 2024-06-27 21:35:28,254] Trial 20 finished with value: 0.07587074294142096 and parameters: {'regressor': 'SVR', 'svr_c': 37.940219422670566, 'svr_epsilon': 0.7059492484824007, 'svr_kernel': 'linear'}. Best is trial 2 with value: 0.1046299394068239.
# [I 2024-06-27 21:35:28,264] Trial 21 finished with value: 0.06795926963982309 and parameters: {'regressor': 'SVR', 'svr_c': 32.695366178249046, 'svr_epsilon': 0.6990995833517283, 'svr_kernel': 'linear'}. Best is trial 2 with value: 0.1046299394068239.
# [I 2024-06-27 21:35:28,486] Trial 22 finished with value: -0.18232101481374233 and parameters: {'regressor': 'SVR', 'svr_c': 0.44352591514324335, 'svr_epsilon': 0.6427432212718982, 'svr_kernel': 'linear'}. Best is trial 2 with value: 0.1046299394068239.
# [I 2024-06-27 21:35:29,051] Trial 23 finished with value: -0.05225269191616584 and parameters: {'regressor': 'SVR', 'svr_c': 0.0640379090441228, 'svr_epsilon': 0.024956769315341642, 'svr_kernel': 'rbf'}. Best is trial 2 with value: 0.1046299394068239.
# [I 2024-06-27 21:35:29,100] Trial 24 finished with value: -0.049579495707321494 and parameters: {'regressor': 'SVR', 'svr_c': 0.14845230963501474, 'svr_epsilon': 0.011064709666187571, 'svr_kernel': 'rbf'}. Best is trial 2 with value: 0.1046299394068239.
# [I 2024-06-27 21:35:31,739] Trial 27 finished with value: -0.041107046793762 and parameters: {'regressor': 'XGBoost', 'xgb_n_estimators': 56, 'xgb_max_depth': 3, 'xgb_learning_rate': 0.010564102493300344, 'xgb_subsample': 0.9884806381699025, 'xgb_colsample_bytree': 0.9830418087203354, 'xgb_gamma': 0.008416241589944917}. Best is trial 2 with value: 0.1046299394068239.
# [I 2024-06-27 21:35:31,813] Trial 11 finished with value: -0.13295217902344533 and parameters: {'regressor': 'XGBoost', 'xgb_n_estimators': 411, 'xgb_max_depth': 19, 'xgb_learning_rate': 0.0339074030264767, 'xgb_subsample': 0.7566410418969793, 'xgb_colsample_bytree': 0.9614242730845963, 'xgb_gamma': 3.1375386371227214}. Best is trial 2 with value: 0.1046299394068239.
# [I 2024-06-27 21:35:32,220] Trial 6 finished with value: -0.04134606484215566 and parameters: {'regressor': 'XGBoost', 'xgb_n_estimators': 447, 'xgb_max_depth': 16, 'xgb_learning_rate': 0.09288930849065966, 'xgb_subsample': 0.8913762442108992, 'xgb_colsample_bytree': 0.817743429873078, 'xgb_gamma': 3.8265372599304253}. Best is trial 2 with value: 0.1046299394068239.
# [I 2024-06-27 21:35:32,288] Trial 28 finished with value: -3827.5686149216294 and parameters: {'regressor': 'SVR', 'svr_c': 343.8763190298984, 'svr_epsilon': 0.1209512385002946, 'svr_kernel': 'sigmoid'}. Best is trial 2 with value: 0.1046299394068239.
# [I 2024-06-27 21:35:32,402] Trial 29 finished with value: -2470.368552876173 and parameters: {'regressor': 'SVR', 'svr_c': 276.681475104931, 'svr_epsilon': 0.11679776742977373, 'svr_kernel': 'sigmoid'}. Best is trial 2 with value: 0.1046299394068239.
# [I 2024-06-27 21:35:33,210] Trial 30 finished with value: -2668.4826016215584 and parameters: {'regressor': 'SVR', 'svr_c': 287.4809632260456, 'svr_epsilon': 0.10980033319894315, 'svr_kernel': 'sigmoid'}. Best is trial 2 with value: 0.1046299394068239.
# [I 2024-06-27 21:35
 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:35:58,296] Trial 83 finished with value: 0.07419001403613593 and parameters: {'regressor': 'SVR', 'svr_c': 166.10167141438578, 'svr_epsilon': 0.14559517634003355, 'svr_kernel': 'poly'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:35:58,312] Trial 84 finished with value: -0.10014137242635153 and parameters: {'regressor': 'SVR', 'svr_c': 240.27519165657256, 'svr_epsilon': 0.0417021708129267, 'svr_kernel': 'rbf'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:35:58,315] Trial 85 finished with value: -0.095807541962763 and parameters: {'regressor': 'SVR', 'svr_c': 248.63072831159218, 'svr_epsilon': 0.03887110933451885, 'svr_kernel': 'rbf'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:35:58,409] Trial 86 finished with value: -0.09966120142634267 and parameters: {'regressor': 'SVR', 'svr_c': 241.0778452488446, 'svr_epsilon': 0.050058920245757726, 'svr_kernel': 'rbf'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:35:58,435] Trial 87 finished with value: -0.09598204700670158 and parameters: {'regressor': 'SVR', 'svr_c': 248.61156964981106, 'svr_epsilon': 0.045065070303792094, 'svr_kernel': 'rbf'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:35:58,633] Trial 88 finished with value: -0.08656566080609514 and parameters: {'regressor': 'SVR', 'svr_c': 249.959188645242, 'svr_epsilon': 0.10964701968062832, 'svr_kernel': 'rbf'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:35:58,771] Trial 90 finished with value: 0.09119627557938836 and parameters: {'regressor': 'SVR', 'svr_c': 55.96760992618235, 'svr_epsilon': 0.5738516086650245, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:35:58,799] Trial 91 finished with value: 0.12793623759498435 and parameters: {'regressor': 'SVR', 'svr_c': 52.73861823231428, 'svr_epsilon': 0.09490870568664353, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:35:58,887] Trial 89 finished with value: -0.39580885465611165 and parameters: {'regressor': 'SVR', 'svr_c': 323.5205870043791, 'svr_epsilon': 0.04691561958899488, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:35:59,093] Trial 62 finished with value: -0.12050723888475554 and parameters: {'regressor': 'XGBoost', 'xgb_n_estimators': 78, 'xgb_max_depth': 32, 'xgb_learning_rate': 0.2844033177575554, 'xgb_subsample': 0.5191888756154521, 'xgb_colsample_bytree': 0.7029628922929896, 'xgb_gamma': 1.029321103906562}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:35:59,240] Trial 98 finished with value: -7.952065387932291 and parameters: {'regressor': 'SVR', 'svr_c': 17.573796045468395, 'svr_epsilon': 0.2211047868481991, 'svr_kernel': 'sigmoid'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:00,448] Trial 36 finished with value: -0.13561258984817362 and parameters: {'regressor': 'RandomForest', 'rf_n_estimators': 499, 'rf_max_depth': 2, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 4, 'rf_max_features': 'log2'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:03,003] Trial 93 finished with value: -0.06713700864751648 and parameters: {'regressor': 'LightGBM', 'lgb_n_estimators': 289, 'lgb_max_depth': 21, 'lgb_learning_rate': 0.07793118295760097, 'lgb_num_leaves': 150, 'lgb_min_child_samples': 67, 'lgb_subsample': 0.5087762194561156, 'lgb_colsample_bytree': 0.5104832536387728}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:03,078] Trial 101 finished with value: 0.13131282112255976 and parameters: {'regressor': 'SVR', 'svr_c': 68.77853470540022, 'svr_epsilon': 0.21841545807300655, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:03,084] Trial 95 finished with value: -0.06713700864751648 and parameters: {'regressor': 'LightGBM', 'lgb_n_estimators': 277, 'lgb_max_depth': 23, 'lgb_learning_rate': 0.07029089794382196, 'lgb_num_leaves': 134, 'lgb_min_child_samples': 70, 'lgb_subsample': 0.5377989253981911, 'lgb_colsample_bytree': 0.5153961508565448}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:03,120] Trial 96 finished with value: -0.06713700864751648 and parameters: {'regressor': 'LightGBM', 'lgb_n_estimators': 276, 'lgb_max_depth': 21, 'lgb_learning_rate': 0.07115120992717543, 'lgb_num_leaves': 150, 'lgb_min_child_samples': 70, 'lgb_subsample': 0.5290895601030343, 'lgb_colsample_bytree': 0.5015338762542839}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:03,141] Trial 102 finished with value: -0.8069068825379482 and parameters: {'regressor': 'LinearRegression'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:03,173] Trial 103 finished with value: -0.8069068825379482 and parameters: {'regressor': 'LinearRegression'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:03,228] Trial 104 finished with value: -0.8069068825379482 and parameters: {'regressor': 'LinearRegression'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:03,279] Trial 105 finished with value: 0.05455995120476158 and parameters: {'regressor': 'SVR', 'svr_c': 25.02422754960703, 'svr_epsilon': 0.6034537334178548, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:03,294] Trial 94 finished with value: -0.06713700864751648 and parameters: {'regressor': 'LightGBM', 'lgb_n_estimators': 300, 'lgb_max_depth': 20, 'lgb_learning_rate': 0.06830736599865861, 'lgb_num_leaves': 121, 'lgb_min_child_samples': 66, 'lgb_subsample': 0.5086036881816403, 'lgb_colsample_bytree': 0.5048316655350811}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:03,324] Trial 92 finished with value: -0.06713700864751648 and parameters: {'regressor': 'LightGBM', 'lgb_n_estimators': 300, 'lgb_max_depth': 21, 'lgb_learning_rate': 0.06509791828119807, 'lgb_num_leaves': 143, 'lgb_min_child_samples': 68, 'lgb_subsample': 0.5001984118563199, 'lgb_colsample_bytree': 0.5106417121229809}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:03,389] Trial 107 finished with value: 0.05850124354867185 and parameters: {'regressor': 'SVR', 'svr_c': 27.248553057724788, 'svr_epsilon': 0.573413082425706, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:03,463] Trial 108 finished with value: 0.13494594876103128 and parameters: {'regressor': 'SVR', 'svr_c': 74.2122383384032, 'svr_epsilon': 0.22484292084917162, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:03,490] Trial 106 finished with value: -0.3338977729165994 and parameters: {'regressor': 'SVR', 'svr_c': 520.2356110552086, 'svr_epsilon': 0.21715123323468938, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:03,493] Trial 109 finished with value: 0.1326758098144059 and parameters: {'regressor': 'SVR', 'svr_c': 70.3831306104799, 'svr_epsilon': 0.22968967807392468, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:03,497] Trial 97 finished with value: -0.06713700864751648 and parameters: {'regressor': 'LightGBM', 'lgb_n_estimators': 293, 'lgb_max_depth': 20, 'lgb_learning_rate': 0.07415180532963059, 'lgb_num_leaves': 145, 'lgb_min_child_samples': 70, 'lgb_subsample': 0.516713009283878, 'lgb_colsample_bytree': 0.5081054241187183}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:03,546] Trial 110 finished with value: 0.13169189183281735 and parameters: {'regressor': 'SVR', 'svr_c': 68.93119237071213, 'svr_epsilon': 0.23241389163762308, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:03,607] Trial 111 finished with value: 0.13548004833361094 and parameters: {'regressor': 'SVR', 'svr_c': 75.24964923505912, 'svr_epsilon': 0.22247694428269352, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:03,732] Trial 113 finished with value: 0.01963469598802494 and parameters: {'regressor': 'SVR', 'svr_c': 9.920648592787378, 'svr_epsilon': 0.01605818040187286, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:03,753] Trial 99 finished with value: -0.06713700864751648 and parameters: {'regressor': 'LightGBM', 'lgb_n_estimators': 303, 'lgb_max_depth': 21, 'lgb_learning_rate': 0.07192472087100699, 'lgb_num_leaves': 146, 'lgb_min_child_samples': 70, 'lgb_subsample': 0.5157523405749409, 'lgb_colsample_bytree': 0.7060069835912632}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:03,792] Trial 114 finished with value: 0.1280634555746359 and parameters: {'regressor': 'SVR', 'svr_c': 54.06731902173741, 'svr_epsilon': 0.00937294318157952, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:03,794] Trial 115 finished with value: 0.11751421493069081 and parameters: {'regressor': 'SVR', 'svr_c': 52.07375669270639, 'svr_epsilon': 0.2516925414706932, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:03,816] Trial 117 finished with value: -0.07828138396064913 and parameters: {'regressor': 'SVR', 'svr_c': 1.3073359801883113, 'svr_epsilon': 0.12084663818928999, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:03,821] Trial 116 finished with value: -0.06325527602179204 and parameters: {'regressor': 'SVR', 'svr_c': 1.2650643404726551, 'svr_epsilon': 0.010617289557347137, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:03,912] Trial 112 finished with value: -0.2653997373130576 and parameters: {'regressor': 'SVR', 'svr_c': 485.555054743656, 'svr_epsilon': 0.2574004109839291, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:03,994] Trial 122 finished with value: 0.08057267814898503 and parameters: {'regressor': 'SVR', 'svr_c': 156.0674924830447, 'svr_epsilon': 0.28448523592283514, 'svr_kernel': 'poly'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:04,014] Trial 123 finished with value: -657.3486082070485 and parameters: {'regressor': 'SVR', 'svr_c': 143.37564665003282, 'svr_epsilon': 0.27375215477598286, 'svr_kernel': 'sigmoid'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:04,048] Trial 118 finished with value: 0.08933176123184783 and parameters: {'regressor': 'SVR', 'svr_c': 136.98468484883978, 'svr_epsilon': 0.25940374640134595, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:04,067] Trial 124 finished with value: -651.7573006120556 and parameters: {'regressor': 'SVR', 'svr_c': 142.71141690133643, 'svr_epsilon': 0.4824696904400528, 'svr_kernel': 'sigmoid'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:04,127] Trial 121 finished with value: 0.006783028469443897 and parameters: {'regressor': 'SVR', 'svr_c': 161.47328119375175, 'svr_epsilon': 0.12498456860828876, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:04,134] Trial 119 finished with value: 0.052173422554373 and parameters: {'regressor': 'SVR', 'svr_c': 143.93038408906915, 'svr_epsilon': 0.12741760554276327, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:04,137] Trial 120 finished with value: 0.06404349265933647 and parameters: {'regressor': 'SVR', 'svr_c': 138.61099476675454, 'svr_epsilon': 0.12104161348077107, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:04,218] Trial 125 finished with value: -487.34852438690524 and parameters: {'regressor': 'SVR', 'svr_c': 123.70574471742394, 'svr_epsilon': 0.19484249766424247, 'svr_kernel': 'sigmoid'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:04,232] Trial 126 finished with value: -0.3078366550655203 and parameters: {'regressor': 'SVR', 'svr_c': 0.0016179938871766777, 'svr_epsilon': 0.48861201962876954, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:04,296] Trial 127 finished with value: 0.10954531472777249 and parameters: {'regressor': 'SVR', 'svr_c': 35.06186946869705, 'svr_epsilon': 0.1951874821633774, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:04,307] Trial 100 finished with value: -0.06713700864751648 and parameters: {'regressor': 'LightGBM', 'lgb_n_estimators': 295, 'lgb_max_depth': 21, 'lgb_learning_rate': 0.06939048012848131, 'lgb_num_leaves': 150, 'lgb_min_child_samples': 68, 'lgb_subsample': 0.5024025878769618, 'lgb_colsample_bytree': 0.7041780915050688}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:04,351] Trial 128 finished with value: 0.13455778218389977 and parameters: {'regressor': 'SVR', 'svr_c': 74.08874513973512, 'svr_epsilon': 0.2049601629421253, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:04,401] Trial 129 finished with value: 0.1361385572747076 and parameters: {'regressor': 'SVR', 'svr_c': 83.34567106090621, 'svr_epsilon': 0.1925769589565315, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:04,406] Trial 131 finished with value: 0.13596299140245888 and parameters: {'regressor': 'SVR', 'svr_c': 78.34730438631226, 'svr_epsilon': 0.18817517616027546, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:04,515] Trial 130 finished with value: 0.1360526117276218 and parameters: {'regressor': 'SVR', 'svr_c': 78.8530001211418, 'svr_epsilon': 0.19067421806596702, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:04,535] Trial 132 finished with value: 0.13376170375907925 and parameters: {'regressor': 'SVR', 'svr_c': 70.42546454049833, 'svr_epsilon': 0.18784743470776624, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:04,580] Trial 133 finished with value: 0.1353986627410334 and parameters: {'regressor': 'SVR', 'svr_c': 75.91355453619326, 'svr_epsilon': 0.19220623660794786, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:04
}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:14,835] Trial 146 finished with value: -0.1014472497555265 and parameters: {'regressor': 'RandomForest', 'rf_n_estimators': 249, 'rf_max_depth': 31, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:14,843] Trial 159 finished with value: -0.019673846563042517 and parameters: {'regressor': 'SVR', 'svr_c': 189.869103908767, 'svr_epsilon': 0.2155367586432735, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:14,847] Trial 160 finished with value: 0.07928106402394657 and parameters: {'regressor': 'SVR', 'svr_c': 199.78314821113912, 'svr_epsilon': 0.16174645771086518, 'svr_kernel': 'poly'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:14,848] Trial 158 finished with value: 0.13442901382779457 and parameters: {'regressor': 'SVR', 'svr_c': 95.76049570371566, 'svr_epsilon': 0.2208842418178554, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:14,936] Trial 163 finished with value: 0.12977245382011582 and parameters: {'regressor': 'SVR', 'svr_c': 59.461449861711316, 'svr_epsilon': 0.1657487118238262, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:14,946] Trial 161 finished with value: 0.07923584824696354 and parameters: {'regressor': 'SVR', 'svr_c': 201.08265769927465, 'svr_epsilon': 0.16699344453991072, 'svr_kernel': 'poly'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:14,986] Trial 162 finished with value: -0.08515558355452461 and parameters: {'regressor': 'SVR', 'svr_c': 210.66439162232834, 'svr_epsilon': 0.1652435530147109, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:15,045] Trial 167 finished with value: 0.1148982864379529 and parameters: {'regressor': 'SVR', 'svr_c': 56.94378266936922, 'svr_epsilon': 0.374792298505854, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:15,049] Trial 166 finished with value: 0.11409278136157894 and parameters: {'regressor': 'SVR', 'svr_c': 53.04105818304207, 'svr_epsilon': 0.3743015616540724, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:15,064] Trial 164 finished with value: -0.06791450857029939 and parameters: {'regressor': 'SVR', 'svr_c': 201.48698137135784, 'svr_epsilon': 0.1658206995839908, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:15,072] Trial 165 finished with value: -0.08586703658573591 and parameters: {'regressor': 'SVR', 'svr_c': 213.28127481005805, 'svr_epsilon': 0.17184740626933243, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:15,108] Trial 168 finished with value: 0.11481629018402932 and parameters: {'regressor': 'SVR', 'svr_c': 61.255292437679024, 'svr_epsilon': 0.3765107855962956, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:15,180] Trial 171 finished with value: 0.11417275821136319 and parameters: {'regressor': 'SVR', 'svr_c': 53.042803095912305, 'svr_epsilon': 0.3725552242415401, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:15,186] Trial 170 finished with value: 0.12160899110158223 and parameters: {'regressor': 'SVR', 'svr_c': 112.27383282585362, 'svr_epsilon': 0.36452361514805937, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:15,193] Trial 169 finished with value: 0.11818669783518283 and parameters: {'regressor': 'SVR', 'svr_c': 110.43611754812542, 'svr_epsilon': 0.39276160206656807, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:15,271] Trial 172 finished with value: 0.13048807692371925 and parameters: {'regressor': 'SVR', 'svr_c': 109.69146109578368, 'svr_epsilon': 0.2760534668375531, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:15,273] Trial 173 finished with value: 0.1159857450179312 and parameters: {'regressor': 'SVR', 'svr_c': 121.9392699213093, 'svr_epsilon': 0.264238775893912, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:15,282] Trial 175 finished with value: 0.1194476626865549 and parameters: {'regressor': 'SVR', 'svr_c': 119.49263960455899, 'svr_epsilon': 0.26269269560859815, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# [I 2024-06-27 21:36:15,310] Trial 174 finished with value: 0.13197637930351866 and parameters: {'regressor': 'SVR', 'svr_c': 108.32913986758705, 'svr_epsilon': 0.2602512340027491, 'svr_kernel': 'linear'}. Best is trial 43 with value: 0.136782876568375.
# ...
# [I 2024-06-27 21:37:15,499] Trial 673 finished with value: 0.13674746275055616 and parameters: {'regressor': 'SVR', 'svr_c': 90.09979015986998, 'svr_epsilon': 0.241207335949544, 'svr_kernel': 'linear'}. Best is trial 334 with value: 0.13724482580929642.
# [I 2024-06-27 21:37:15,574] Trial 674 finished with value: -0.014759420581431048 and parameters: {'regressor': 'SVR', 'svr_c': 5.90789917122319, 'svr_epsilon': 0.04126205986733751, 'svr_kernel': 'linear'}. Best is trial 334 with value: 0.13724482580929642.
# [I 2024-06-27 21:37:15,658] Trial 675 finished with value: 0.11772561984490208 and parameters: {'regressor': 'SVR', 'svr_c': 42.29015892971311, 'svr_epsilon': 0.19531707853631242, 'svr_kernel': 'linear'}. Best is trial 334 with value: 0.13724482580929642.
# [I 2024-06-27 21:37:15,769] Trial 676 finished with value: 0.1355558451104369 and parameters: {'regressor': 'SVR', 'svr_c': 92.80467764503605, 'svr_epsilon': 0.2288023462607505, 'svr_kernel': 'linear'}. Best is trial 334 with value: 0.13724482580929642.
# [I 2024-06-27 21:37:16,008] Trial 677 finished with value: -0.41679490837667715 and parameters: {'regressor': 'SVR', 'svr_c': 652.2773714895972, 'svr_epsilon': 0.1810164617234444, 'svr_kernel': 'linear'}. Best is trial 334 with value: 0.13724482580929642.
# [I 2024-06-27 21:37:16,189] Trial 678 finished with value: -0.10471157036812681 and parameters: {'regressor': 'SVR', 'svr_c': 252.7946459000346, 'svr_epsilon': 0.24120553222494687, 'svr_kernel': 'linear'}. Best is trial 334 with value: 0.13724482580929642.
# [I 2024-06-27 21:37:16,224] Trial 679 finished with value: -0.8069068825379482 and parameters: {'regressor': 'LinearRegression'}. Best is trial 334 with value: 0.13724482580929642.
# [I 2024-06-27 21:37:16,324] Trial 680 finished with value: 0.13562354437667723 and parameters: {'regressor': 'SVR', 'svr_c': 75.83750822763251, 'svr_epsilon': 0.2119166790223911, 'svr_kernel': 'linear'}. Best is trial 334 with value: 0.13724482580929642.
# [I 2024-06-27 21:37:16,403] Trial 681 finished with value: -0.1435648994764768 and parameters: {'regressor': 'SVR', 'svr_c': 0.0028074341825861395, 'svr_epsilon': 0.24928513845379877, 'svr_kernel': 'linear'}. Best is trial 334 with value: 0.13724482580929642.
# [I 2024-06-27 21:37:16,523] Trial 682 finished with value: 0.12474947151621545 and parameters: {'regressor': 'SVR', 'svr_c': 107.07521298238098, 'svr_epsilon': 0.18571212850840677, 'svr_kernel': 'linear'}. Best is trial 334 with value: 0.13724482580929642.
# [I 2024-06-27 21:37:16,629] Trial 683 finished with value: 0.1318314620582729 and parameters: {'regressor': 'SVR', 'svr_c': 79.20678928337973, 'svr_epsilon': 0.3053537777620734, 'svr_kernel': 'linear'}. Best is trial 334 with value: 0.13724482580929642.
# [I 2024-06-27 21:37:16,714] Trial 684 finished with value: 0.11460725761687085 and parameters: {'regressor': 'SVR', 'svr_c': 45.10557564199139, 'svr_epsilon': 0.2268344503820472, 'svr_kernel': 'linear'}. Best is trial 334 with value: 0.13724482580929642.
# [I 2024-06-27 21:37:16,811] Trial 685 finished with value: 0.12781783715715656 and parameters: {'regressor': 'SVR', 'svr_c': 63.65174429854703, 'svr_epsilon': 0.26483723186011343, 'svr_kernel': 'linear'}. Best is trial 334 with value: 0.13724482580929642.
# [I 2024-06-27 21:37:16,929] Trial 686 finished with value: 0.12344897384855016 and parameters: {'regressor': 'SVR', 'svr_c': 112.5512092994376, 'svr_epsilon': 0.20521440325598136, 'svr_kernel': 'linear'}. Best is trial 334 with value: 0.13724482580929642.
# [I 2024-06-27 21:37:17,756] Trial 658 finished with value: -0.06713700864751648 and parameters: {'regressor': 'LightGBM', 'lgb_n_estimators': 481, 'lgb_max_depth': 7, 'lgb_learning_rate': 0.01904525867900804, 'lgb_num_leaves': 39, 'lgb_min_child_samples': 86, 'lgb_subsample': 0.7697731519260508, 'lgb_colsample_bytree': 0.893382984473307}. Best is trial 334 with value: 0.13724482580929642.
# [I 2024-06-27 21:37:17,859] Trial 659 finished with value: -0.06713700864751648 and parameters: {'regressor': 'LightGBM', 'lgb_n_estimators': 497, 'lgb_max_depth': 7, 'lgb_learning_rate': 0.01787594516715585, 'lgb_num_leaves': 38, 'lgb_min_child_samples': 39, 'lgb_subsample': 0.7754003023768434, 'lgb_colsample_bytree': 0.9059571253684128}. Best is trial 334 with value: 0.13724482580929642.
# [I 2024-06-27 21:37:17,885] Trial 688 finished with value: 0.13301177489704297 and parameters: {'regressor': 'SVR', 'svr_c': 91.44706739391079, 'svr_epsilon': 0.3296311697974502, 'svr_kernel': 'linear'}. Best is trial 334 with value: 0.13724482580929642.
# [I 2024-06-27 21:37:17,991] Trial 664 finished with value: -0.06713700864751648 and parameters: {'regressor': 'LightGBM', 'lgb_n_estimators': 481, 'lgb_max_depth': 8, 'lgb_learning_rate': 0.018022465901742456, 'lgb_num_leaves': 40, 'lgb_min_child_samples': 40, 'lgb_subsample': 0.7751370403836831, 'lgb_colsample_bytree': 0.9436752970540113}. Best is trial 334 with value: 0.13724482580929642.
# [I 2024-06-27 21:37:18,081] Trial 662 finished with value: -0.06713700864751648 and parameters: {'regressor': 'LightGBM', 'lgb_n_estimators': 496, 'lgb_max_depth': 7, 'lgb_learning_rate': 0.017442859710044518, 'lgb_num_leaves': 34, 'lgb_min_child_samples': 39, 'lgb_subsample': 0.787721276928916, 'lgb_colsample_bytree': 0.9025255545614275}. Best is trial 334 with value: 0.13724482580929642.
# [I 2024-06-27 21:37:18,100] Trial 690 finished with value: 0.127024048934454 and parameters: {'regressor': 'SVR', 'svr_c': 62.0218842866623, 'svr_epsilon': 0.2583189852351385, 'svr_kernel': 'linear'}. Best is trial 334 with value: 0.13724482580929642.
# [I 2024-06-27 21:37:18,102] Trial 689 finished with value: 0.1372998106711823 and parameters: {'regressor': 'SVR', 'svr_c': 90.28069919021961, 'svr_epsilon': 0.2539728991636329, 'svr_kernel': 'linear'}. Best is trial 689 with value: 0.1372998106711823.
# [I 2024-06-27 21:37:18,257] Trial 691 finished with value: 0.12943952544694837 and parameters: {'regressor': 'SVR', 'svr_c': 65.90206993330266, 'svr_epsilon': 0.25434838398518556, 'svr_kernel': 'linear'}. Best is trial 689 with value: 0.1372998106711823.
# [I 2024-06-27 21:37:18,381] Trial 692 finished with value: 0.12842231548824487 and parameters: {'regressor': 'SVR', 'svr_c': 64.21390716979447, 'svr_epsilon': 0.253566536505984, 'svr_kernel': 'linear'}. Best is trial 689 with value: 0.1372998106711823.
# [I 2024-06-27 21:37:18,415] Trial 694 finished with value: 0.13402093903113532 and parameters: {'regressor': 'SVR', 'svr_c': 103.89126419524992, 'svr_epsilon': 0.293097735436583, 'svr_kernel': 'linear'}. Best is trial 689 with value: 0.1372998106711823.
# [I 2024-06-27 21:37:18,439] Trial 693 finished with value: 0.12094998277595422 and parameters: {'regressor': 'SVR', 'svr_c': 118.13593280531084, 'svr_epsilon': 0.2901492489965551, 'svr_kernel': 'linear'}. Best is trial 689 with value: 0.1372998106711823.
# [I 2024-06-27 21:37:18,442] Trial 660 finished with value: -0.26533771837059367 and parameters: {'regressor': 'LightGBM', 'lgb_n_estimators': 484, 'lgb_max_depth': 7, 'lgb_learning_rate': 0.04871244530385039, 'lgb_num_leaves': 33, 'lgb_min_child_samples': 14, 'lgb_subsample': 0.7771603658531846, 'lgb_colsample_bytree': 0.8979943639469252}. Best is trial 689 with value: 0.1372998106711823.
# [I 2024-06-27 21:37:18,608] Trial 695 finished with value: 0.12779581215171795 and parameters: {'regressor': 'SVR', 'svr_c': 110.75802690182984, 'svr_epsilon': 0.3064061545431581, 'svr_kernel': 'linear'}. Best is trial 689 with value: 0.1372998106711823.
# [I 2024-06-27 21:37:18,748] Trial 696 finished with value: 0.12300178587025487 and parameters: {'regressor': 'SVR', 'svr_c': 116.22798274967279, 'svr_epsilon': 0.2950272392415435, 'svr_kernel': 'linear'}. Best is trial 689 with value: 0.1372998106711823.
# [I 2024-06-27 21:37:18,789] Trial 698 finished with value: 0.0949146520551073 and parameters: {'regressor': 'SVR', 'svr_c': 93.37758412844413, 'svr_epsilon': 0.5279826070511083, 'svr_kernel': 'linear'}. Best is trial 689 with value: 0.1372998106711823.
# [I 2024-06-27 21:37:18,814] Trial 699 finished with value: 0.11681761787136469 and parameters: {'regressor': 'SVR', 'svr_c': 88.37339277308384, 'svr_epsilon': 0.0029877844007719194, 'svr_kernel': 'linear'}. Best is trial 689 with value: 0.1372998106711823.
# [I 2024-06-27 21:37:18,816] Trial 663 finished with value: -0.15555551796526607 and parameters: {'regressor': 'LightGBM', 'lgb_n_estimators': 498, 'lgb_max_depth': 6, 'lgb_learning_rate': 0.01895628879435198, 'lgb_num_leaves': 36, 'lgb_min_child_samples': 15, 'lgb_subsample': 0.7849197457158488, 'lgb_colsample_bytree': 0.9064442639001415}. Best is trial 689 with value: 0.1372998106711823.
# [I 2024-06-27 21:37:18,931] Trial 697 finished with value: -0.10165235167819156 and parameters: {'regressor': 'SVR', 'svr_c': 222.7839238637776, 'svr_epsilon': 0.1725579023199612, 'svr_kernel': 'linear'}. Best is trial 689 with value: 0.1372998106711823.
# [I 2024-06-27 21:37:19,006] Trial 700 finished with value: 0.1353795530838548 and parameters: {'regressor': 'SVR', 'svr_c': 87.41970469295934, 'svr_epsilon': 0.20853610119954585, 'svr_kernel': 'linear'}. Best is trial 689 with value: 0.1372998106711823.
# [I 2024-06-27 21:37:19,093] Trial 687 finished with value: -0.06713700864751648 and parameters: {'regressor': 'LightGBM', 'lgb_n_estimators': 125, 'lgb_max_depth': 17, 'lgb_learning_rate': 0.04777417543287393, 'lgb_num_leaves': 112, 'lgb_min_child_samples': 86, 'lgb_subsample': 0.596148853836115, 'lgb_colsample_bytree': 0.7816720501346458}. Best is trial 689 with value: 0.1372998106711823.
# [I 2024-06-27 21:37:19,641] Trial 670 finished with value: -0.030780735754089218 and parameters: {'regressor': 'LightGBM', 'lgb_n_estimators': 500, 'lgb_max_depth': 7, 'lgb_learning_rate': 0.01722656659751274, 'lgb_num_leaves': 38, 'lgb_min_child_samples': 16, 'lgb_subsample': 0.7502033745372295, 'lgb_colsample_bytree': 0.9385992580485281}. Best is trial 689 with value: 0.1372998106711823.
# [I 2024-06-27 21:37:19,862] Trial 701 finished with value: -0.18441577823637556 and parameters: {'regressor': 'SVR', 'svr_c': 208.44412581483323, 'svr_epsilon': 0.005402057444190277, 'svr_kernel': 'linear'}. Best is trial 689 with value: 0.1372998106711823.
# [I 2024-06-27 21:37:20,108] Trial 705 finished with value: 0.10831066281751925 and parameters: {'regressor': 'SVR', 'svr_c': 35.28433318843954, 'svr_epsilon': 0.21496585737506266, 'svr_kernel': 'linear'}. Best is trial 689 with value: 0.1372998106711823.
# [I 2024-06-27 21:37:20,364] Trial 707 finished with value: -0.08364922206645672 and parameters: {'regressor': 'SVR', 'svr_c': 35.546566480129435, 'svr_epsilon': 0.22567392817982498, 'svr_kernel': 'poly'}. Best is trial 689 with value: 0.1372998106711823.
# [I 2024-06-27 21:37:20,791] Trial 708 finished with value: -0.11099802025286623 and parameters: {'regressor': 'SVR', 'svr_c': 35.737203079213, 'svr_epsilon': 0.3412326997598215, 'svr_kernel': 'poly'}. Best is trial 689 with value: 0.1372998106711823.
# [I 2024-06-27 21:37:23,540] Trial 703 finished with value: -0.14899429725989966 and parameters: {'regressor': 'RandomForest', 'rf_n_estimators': 96, 'rf_max_depth': 5, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 4, 'rf_max_features': 'log2'}. Best is trial 689 with value: 0.1372998106711823.
# [I 2024-06-27 21:37:23,994] Trial 706 finished with value: -0.14345230729990527 and parameters: {'regressor': 'RandomForest', 'rf_n_estimators': 94, 'rf_max_depth': 5, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 4, 'rf_max_features': 'log2'}. Best is trial 689 with value: 0.1372998106711823.
# [I 2024-06-27 21:37:24,334] Trial 709 finished with value: -0.14807047467079887 and parameters: {'regressor': 'RandomForest', 'rf_n_estimators': 96, 'rf_max_depth': 6, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 4, 'rf_max_features': 'log2'}. Best is trial 689 with value: 0.1372998106711823.
# [I 2024-06-27 21:37:24,700] Trial 710 finished with value: -0.13915488315116314 and parameters: {'regressor': 'RandomForest', 'rf_n_estimators': 97, 'rf_max_depth': 6, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 4, 'rf_max_features': 'log2'}. Best is trial 689 with value: 0.1372998106711823.
# [I 2024-06-27 21:37:24,771] Trial 711 finished with value: -0.1463129494787499 and parameters: {'regressor': 'RandomForest', 'rf_n_estimators': 92, 'rf_max_depth': 5, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 4, 'rf_max_features': 'log2'}. Best is trial 689 with value: 0.1372998106711823.
# [I 2024-06-27 21:37:24,931] Trial 712 finished with value: -0.14345230729990527 and parameters: {'regressor': 'RandomForest', 'rf_n_estimators': 94, 'rf_max_depth': 5, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 4, 'rf_max_features': 'log2'}. Best is trial 689 with value: 0.1372998106711823.
# [I 2024-06-27 21:37:27,812] Trial 704 finished with value: -0.14615480947937573 and parameters: {'regressor': 'RandomForest', 'rf_n_estimators': 393, 'rf_max_depth': 6, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 4, 'rf_max_features': 'log2'}. Best is trial 689 with value: 0.1372998106711823.
# [I 2024-06-27 21:37:27,904] Trial 702 finished with value: -0.14302417313912236 and parameters: {'regressor': 'RandomForest', 'rf_n_estimators': 411, 'rf_max_depth': 5, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 4, 'rf_max_features': 'log2'}. Best is trial 689 with value: 0.1372998106711823.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 63
#      61 # Optuna 최적화
#      62 study = optuna.create_study(direction='maximize')
# ---> 63 study.optimize(objective, n_trials=1000, n_jobs=-1)
#      65 # 최적의 하이퍼파라미터로 모델 학습
#      66 best_params = study.best_params
#
# File c:\Users\user\anaconda3\Lib\site-packages\optuna\study\study.py:451, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     348 def optimize(
#     349     self,
#     350     func: ObjectiveFuncType,
#    (...)
#     357     show_progress_bar: bool = False,
#     358 ) -> None:
#     359     """Optimize an objective function.
#     360
#     361     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     449             If nested invocation of this method occurs.
#     450     """
# --> 451     _optimize(
#     452         study=self,
#     453         func=func,
#     454         n_trials=n_trials,
#     455         timeout=timeout,
#     456         n_jobs=n_jobs,
#     457         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     458         callbacks=callbacks,
#     459         gc_after_trial=gc_after_trial,
#     460         show_progress_bar=show_progress_bar,
#     461     )
#
# File c:\Users\user\anaconda3\Lib\site-packages\optuna\study\_optimize.py:96, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      93     break
#      95 if len(futures) >= n_jobs:
# ---> 96     completed, futures = wait(futures, return_when=FIRST_COMPLETED)
#      97     # Raise if exception occurred in executing the completed futures.
#      98     for f in completed:
#
# File c:\Users\user\anaconda3\Lib\concurrent\futures\_base.py:305, in wait(fs, timeout, return_when)
#     301         return DoneAndNotDoneFutures(done, not_done)
#     303     waiter = _create_and_install_waiters(fs, return_when)
# --> 305 waiter.event.wait(timeout)
#     306 for f in fs:
#     307     with f._condition:
#
# File c:\Users\user\anaconda3\Lib\threading.py:629, in Event.wait(self, timeout)
#     627 signaled = self._flag
#     628 if not signaled:
# --> 629     signaled = self._cond.wait(timeout)
#     630 return signaled
#
# File c:\Users\user\anaconda3\Lib\threading.py:327, in Condition.wait(self, timeout)
#     325 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     326     if timeout is None:
# --> 327         waiter.acquire()
#     328         gotit = True
#     329     else:
#
# KeyboardInterrupt:
