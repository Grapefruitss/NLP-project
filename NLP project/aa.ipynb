# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.linear_model import LogisticRegression
import csv
import optuna
import numpy as np

# %%
file_path = r'.\crawling_data\preprocessed_essay.csv'

# 자소서 리스트화
documents = []
with open(file_path, 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        documents.append(row[0])

import random

documents = documents[:77] + random.sample(documents[-142:-15], 62) + documents[-15:]

# %%
# 전문가 평점 3점 이상인 상위 175개는 label에 1, 나머지 하위는 label에 0 값 부여
# 분류 예측용 label
labels = []
for i in range(154):
    if i < 77:
        labels.append(1)
    else:
        labels.append(0)

# %%
# 불용어 리스트 가져오기
stop_words = set(stopwords.words('english'))

def preprocess(text):
    tokens = word_tokenize(text)
    filtered_tokens = [word for word in tokens if word.isalpha() and word not in stop_words]
    return filtered_tokens

documents_corpus = []
for document in documents:
    documents_corpus.append(preprocess(document))

# %%
# Tagged Corpus 생성.
# 모델 학습에 필요한 형태로 변환.
my_tagged_corpus = [TaggedDocument(words=my_words, tags=[i]) for i, my_words in enumerate(documents_corpus)]

# %%
def objective(trial):
    # 하이퍼파라미터 샘플링
    vector_size = trial.suggest_int('vector_size', 20, 100)
    window = trial.suggest_int('window', 2, 10)
    min_count = trial.suggest_int('min_count', 1, 5)
    epochs = trial.suggest_int('epochs', 10, 50)

    # Doc2Vec 모델 생성 및 학습
    model = Doc2Vec(vector_size=vector_size, window=window, min_count=min_count, epochs=epochs)
    model.build_vocab(my_tagged_corpus)
    model.train(my_tagged_corpus, total_examples=model.corpus_count, epochs=model.epochs)

# 레이블별로 코사인 유사도 평가
    label_0_vectors = [model.dv[i] for i, label in enumerate(labels) if label == 0]
    label_1_vectors = [model.dv[i] for i, label in enumerate(labels) if label == 1]

    # 레이블 0 문서들 간의 유사도 평균
    similarity_scores_0 = []
    for i in range(len(label_0_vectors)):
        for j in range(i + 1, len(label_0_vectors)):
            similarity_scores_0.append(cosine_similarity([label_0_vectors[i]], [label_0_vectors[j]])[0][0])
    mean_similarity_0 = np.mean(similarity_scores_0) if similarity_scores_0 else 0

    # 레이블 1 문서들 간의 유사도 평균
    similarity_scores_1 = []
    for i in range(len(label_1_vectors)):
        for j in range(i + 1, len(label_1_vectors)):
            similarity_scores_1.append(cosine_similarity([label_1_vectors[i]], [label_1_vectors[j]])[0][0])
    mean_similarity_1 = np.mean(similarity_scores_1) if similarity_scores_1 else 0

    # 두 유사도의 평균을 최종 점수로 사용
    final_similarity_score = (mean_similarity_0 + mean_similarity_1) / 2
    
    return final_similarity_score

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

print(f'Best parameters: {study.best_params}')
print(f'Best similarity score: {study.best_value}')
# Out:
# [I 2024-06-27 19:40:41,071] A new study created in memory with name: no-name-824f3068-c2ab-4bf7-85f1-f192ce57c464
# [I 2024-06-27 19:40:44,557] Trial 0 finished with value: 0.3502827286720276 and parameters: {'vector_size': 74, 'window': 10, 'min_count': 5, 'epochs': 24}. Best is trial 0 with value: 0.3502827286720276.
# [I 2024-06-27 19:40:48,391] Trial 1 finished with value: 0.3355942964553833 and parameters: {'vector_size': 21, 'window': 10, 'min_count': 2, 'epochs': 29}. Best is trial 0 with value: 0.3502827286720276.
# [I 2024-06-27 19:40:52,941] Trial 2 finished with value: 0.20533595979213715 and parameters: {'vector_size': 57, 'window': 9, 'min_count': 5, 'epochs': 43}. Best is trial 0 with value: 0.3502827286720276.
# [I 2024-06-27 19:40:57,511] Trial 3 finished with value: 0.2333109974861145 and parameters: {'vector_size': 25, 'window': 9, 'min_count': 4, 'epochs': 44}. Best is trial 0 with value: 0.3502827286720276.
# [I 2024-06-27 19:41:01,658] Trial 4 finished with value: 0.2438947856426239 and parameters: {'vector_size': 28, 'window': 8, 'min_count': 4, 'epochs': 38}. Best is trial 0 with value: 0.3502827286720276.
# [I 2024-06-27 19:41:05,938] Trial 5 finished with value: 0.25603169202804565 and parameters: {'vector_size': 28, 'window': 10, 'min_count': 4, 'epochs': 36}. Best is trial 0 with value: 0.3502827286720276.
# [I 2024-06-27 19:41:10,263] Trial 6 finished with value: 0.2347889244556427 and parameters: {'vector_size': 42, 'window': 10, 'min_count': 3, 'epochs': 40}. Best is trial 0 with value: 0.3502827286720276.
# [I 2024-06-27 19:41:12,964] Trial 7 finished with value: 0.9115045070648193 and parameters: {'vector_size': 22, 'window': 7, 'min_count': 4, 'epochs': 10}. Best is trial 7 with value: 0.9115045070648193.
# [I 2024-06-27 19:41:17,558] Trial 8 finished with value: 0.22745458781719208 and parameters: {'vector_size': 47, 'window': 8, 'min_count': 2, 'epochs': 45}. Best is trial 7 with value: 0.9115045070648193.
# [I 2024-06-27 19:41:20,598] Trial 9 finished with value: 0.7015548944473267 and parameters: {'vector_size': 80, 'window': 6, 'min_count': 4, 'epochs': 16}. Best is trial 7 with value: 0.9115045070648193.
# [I 2024-06-27 19:41:23,466] Trial 10 finished with value: 0.9908800721168518 and parameters: {'vector_size': 96, 'window': 3, 'min_count': 1, 'epochs': 10}. Best is trial 10 with value: 0.9908800721168518.
# [I 2024-06-27 19:41:26,322] Trial 11 finished with value: 0.9901964664459229 and parameters: {'vector_size': 98, 'window': 3, 'min_count': 1, 'epochs': 10}. Best is trial 10 with value: 0.9908800721168518.
# [I 2024-06-27 19:41:29,063] Trial 12 finished with value: 0.9915133118629456 and parameters: {'vector_size': 99, 'window': 3, 'min_count': 1, 'epochs': 10}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:41:32,330] Trial 13 finished with value: 0.7975122928619385 and parameters: {'vector_size': 98, 'window': 2, 'min_count': 1, 'epochs': 19}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:41:35,480] Trial 14 finished with value: 0.787743091583252 and parameters: {'vector_size': 84, 'window': 4, 'min_count': 2, 'epochs': 17}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:41:39,209] Trial 15 finished with value: 0.5809713006019592 and parameters: {'vector_size': 89, 'window': 5, 'min_count': 1, 'epochs': 24}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:41:42,092] Trial 16 finished with value: 0.9323614835739136 and parameters: {'vector_size': 69, 'window': 2, 'min_count': 2, 'epochs': 13}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:41:45,790] Trial 17 finished with value: 0.6385880708694458 and parameters: {'vector_size': 93, 'window': 4, 'min_count': 1, 'epochs': 23}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:41:49,512] Trial 18 finished with value: 0.3263373374938965 and parameters: {'vector_size': 64, 'window': 3, 'min_count': 3, 'epochs': 32}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:41:52,987] Trial 19 finished with value: 0.7182828187942505 and parameters: {'vector_size': 77, 'window': 5, 'min_count': 1, 'epochs': 20}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:41:55,960] Trial 20 finished with value: 0.9084275960922241 and parameters: {'vector_size': 89, 'window': 3, 'min_count': 2, 'epochs': 14}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:41:58,993] Trial 21 finished with value: 0.9821592569351196 and parameters: {'vector_size': 100, 'window': 3, 'min_count': 1, 'epochs': 11}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:42:04,106] Trial 22 finished with value: 0.24673709273338318 and parameters: {'vector_size': 100, 'window': 4, 'min_count': 1, 'epochs': 49}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:42:06,927] Trial 23 finished with value: 0.985011875629425 and parameters: {'vector_size': 92, 'window': 2, 'min_count': 3, 'epochs': 10}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:42:10,151] Trial 24 finished with value: 0.9169224500656128 and parameters: {'vector_size': 85, 'window': 5, 'min_count': 1, 'epochs': 14}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:42:13,433] Trial 25 finished with value: 0.69370436668396 and parameters: {'vector_size': 94, 'window': 3, 'min_count': 2, 'epochs': 20}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:42:17,656] Trial 26 finished with value: 0.463051974773407 and parameters: {'vector_size': 83, 'window': 4, 'min_count': 1, 'epochs': 29}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:42:20,907] Trial 27 finished with value: 0.7710870504379272 and parameters: {'vector_size': 56, 'window': 6, 'min_count': 2, 'epochs': 16}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:42:23,925] Trial 28 finished with value: 0.9707114100456238 and parameters: {'vector_size': 95, 'window': 2, 'min_count': 1, 'epochs': 12}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:42:27,266] Trial 29 finished with value: 0.46520984172821045 and parameters: {'vector_size': 72, 'window': 3, 'min_count': 3, 'epochs': 25}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:42:30,609] Trial 30 finished with value: 0.7709575295448303 and parameters: {'vector_size': 88, 'window': 6, 'min_count': 1, 'epochs': 18}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:42:33,390] Trial 31 finished with value: 0.9796427488327026 and parameters: {'vector_size': 92, 'window': 2, 'min_count': 5, 'epochs': 10}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:42:36,082] Trial 32 finished with value: 0.9852558374404907 and parameters: {'vector_size': 100, 'window': 2, 'min_count': 3, 'epochs': 10}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:42:39,053] Trial 33 finished with value: 0.9122141003608704 and parameters: {'vector_size': 100, 'window': 3, 'min_count': 2, 'epochs': 14}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:42:41,997] Trial 34 finished with value: 0.9221704006195068 and parameters: {'vector_size': 77, 'window': 4, 'min_count': 2, 'epochs': 13}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:42:45,132] Trial 35 finished with value: 0.8243663907051086 and parameters: {'vector_size': 96, 'window': 2, 'min_count': 3, 'epochs': 16}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:42:48,033] Trial 36 finished with value: 0.9249073266983032 and parameters: {'vector_size': 87, 'window': 3, 'min_count': 5, 'epochs': 12}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:42:51,459] Trial 37 finished with value: 0.6434118747711182 and parameters: {'vector_size': 80, 'window': 5, 'min_count': 1, 'epochs': 22}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:42:54,848] Trial 38 finished with value: 0.49046170711517334 and parameters: {'vector_size': 96, 'window': 2, 'min_count': 2, 'epochs': 27}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:42:58,673] Trial 39 finished with value: 0.3577837646007538 and parameters: {'vector_size': 40, 'window': 4, 'min_count': 1, 'epochs': 35}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:43:01,382] Trial 40 finished with value: 0.9817436933517456 and parameters: {'vector_size': 90, 'window': 3, 'min_count': 3, 'epochs': 10}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:43:04,156] Trial 41 finished with value: 0.9851086139678955 and parameters: {'vector_size': 93, 'window': 2, 'min_count': 3, 'epochs': 10}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:43:07,127] Trial 42 finished with value: 0.8432142734527588 and parameters: {'vector_size': 96, 'window': 2, 'min_count': 4, 'epochs': 15}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:43:09,922] Trial 43 finished with value: 0.9464527368545532 and parameters: {'vector_size': 97, 'window': 3, 'min_count': 3, 'epochs': 12}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:43:12,577] Trial 44 finished with value: 0.9834107160568237 and parameters: {'vector_size': 100, 'window': 2, 'min_count': 4, 'epochs': 10}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:43:15,801] Trial 45 finished with value: 0.6333025693893433 and parameters: {'vector_size': 84, 'window': 7, 'min_count': 4, 'epochs': 17}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:43:18,636] Trial 46 finished with value: 0.9509483575820923 and parameters: {'vector_size': 94, 'window': 2, 'min_count': 3, 'epochs': 12}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:43:21,753] Trial 47 finished with value: 0.8832299709320068 and parameters: {'vector_size': 52, 'window': 4, 'min_count': 1, 'epochs': 15}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:43:25,155] Trial 48 finished with value: 0.6472650766372681 and parameters: {'vector_size': 91, 'window': 9, 'min_count': 2, 'epochs': 18}. Best is trial 12 with value: 0.9915133118629456.
# [I 2024-06-27 19:43:27,924] Trial 49 finished with value: 0.8582605123519897 and parameters: {'vector_size': 38, 'window': 3, 'min_count': 5, 'epochs': 13}. Best is trial 12 with value: 0.9915133118629456.
# Best parameters: {'vector_size': 99, 'window': 3, 'min_count': 1, 'epochs': 10}
# Best similarity score: 0.9915133118629456

# %%
best_params = {'vector_size': 99, 'window': 3, 'min_count': 1, 'epochs': 10}

best_vector_size = best_params['vector_size']
best_window = best_params['window']
best_min_count = best_params['min_count']
best_epochs = best_params['epochs']

best_model = Doc2Vec(vector_size=best_vector_size, window=best_window, min_count=best_min_count, epochs=best_epochs)
best_model.build_vocab(my_tagged_corpus)
best_model.train(my_tagged_corpus, total_examples=best_model.corpus_count, epochs=best_model.epochs)

# %%
X_train, X_test, y_train, y_test = train_test_split(documents_corpus, labels, test_size=0.3, random_state=42)

# %%
from sklearn.metrics import f1_score
# 문서 벡터 생성
train_vectors = [best_model.infer_vector(doc) for doc in X_train]
test_vectors = [best_model.infer_vector(doc) for doc in X_test]

def objective(trial):
    classifier_name = trial.suggest_categorical('classifier', ['LogisticRegression', 'SVC', 'RandomForest', 'XGBoost', 'LightGBM'])
    
    if classifier_name == 'LogisticRegression':
        C = trial.suggest_float('C', 1e-5, 1e2, log=True)
        solver = trial.suggest_categorical('solver', ['liblinear', 'lbfgs', 'newton-cg', 'sag', 'saga'])
        classifier_obj = LogisticRegression(C=C, solver=solver, max_iter=1000, random_state=42)
    elif classifier_name == 'SVC':
        C = trial.suggest_float('C', 1e-5, 1e2, log=True)
        kernel = trial.suggest_categorical('kernel', ['linear', 'poly', 'rbf', 'sigmoid'])
        gamma = trial.suggest_categorical('gamma', ['scale', 'auto'])
        classifier_obj = SVC(C=C, kernel=kernel, gamma=gamma, random_state=42)
    elif classifier_name == 'RandomForest':
        n_estimators = trial.suggest_int('n_estimators', 50, 1000)
        max_depth = trial.suggest_int('max_depth', 2, 32, log=True)
        min_samples_split = trial.suggest_int('min_samples_split', 2, 20)
        min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 20)
        classifier_obj = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, min_samples_split=min_samples_split, min_samples_leaf=min_samples_leaf, random_state=42)
    elif classifier_name == 'XGBoost':
        n_estimators = trial.suggest_int('n_estimators', 50, 1000)
        learning_rate = trial.suggest_float('learning_rate', 0.01, 0.3)
        max_depth = trial.suggest_int('max_depth', 2, 32, log=True)
        subsample = trial.suggest_float('subsample', 0.5, 1.0)
        colsample_bytree = trial.suggest_float('colsample_bytree', 0.5, 1.0)
        classifier_obj = XGBClassifier(n_estimators=n_estimators, learning_rate=learning_rate, max_depth=max_depth, subsample=subsample, colsample_bytree=colsample_bytree, random_state=42)
    elif classifier_name == 'LightGBM':
        n_estimators = trial.suggest_int('n_estimators', 50, 1000)
        learning_rate = trial.suggest_float('learning_rate', 0.01, 0.3)
        max_depth = trial.suggest_int('max_depth', 2, 32, log=True)
        num_leaves = trial.suggest_int('num_leaves', 20, 3000, log=True)
        min_child_samples = trial.suggest_int('min_child_samples', 5, 100)
        classifier_obj = LGBMClassifier(n_estimators=n_estimators, learning_rate=learning_rate, max_depth=max_depth, num_leaves=num_leaves, min_child_samples=min_child_samples, random_state=42)

    classifier_obj.fit(train_vectors, y_train)
    y_pred = classifier_obj.predict(test_vectors)
    score = f1_score(y_test, y_pred)
    
    return score

# Optuna로 최적의 하이퍼파라미터 찾기
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=2000, n_jobs=-1)

# 최적의 하이퍼파라미터 출력
best_trial = study.best_trial
print(f'Best trial: {best_trial.value}')
print(f'Best params: {best_trial.params}')

# 최적의 하이퍼파라미터를 사용하여 최종 모델 학습
classifier_name = best_trial.params['classifier']

if classifier_name == 'LogisticRegression':
    best_model = LogisticRegression(C=best_trial.params['C'], solver=best_trial.params['solver'], max_iter=1000, random_state=42)
elif classifier_name == 'SVC':
    best_model = SVC(C=best_trial.params['C'], kernel=best_trial.params['kernel'], gamma=best_trial.params['gamma'], random_state=42)
elif classifier_name == 'RandomForest':
    best_model = RandomForestClassifier(n_estimators=best_trial.params['n_estimators'], max_depth=best_trial.params['max_depth'], min_samples_split=best_trial.params['min_samples_split'], min_samples_leaf=best_trial.params['min_samples_leaf'], random_state=42)
elif classifier_name == 'XGBoost':
    best_model = XGBClassifier(n_estimators=best_trial.params['n_estimators'], learning_rate=best_trial.params['learning_rate'], max_depth=best_trial.params['max_depth'], subsample=best_trial.params['subsample'], colsample_bytree=best_trial.params['colsample_bytree'], random_state=42)
elif classifier_name == 'LightGBM':
    best_model = LGBMClassifier(n_estimators=best_trial.params['n_estimators'], learning_rate=best_trial.params['learning_rate'], max_depth=best_trial.params['max_depth'], num_leaves=best_trial.params['num_leaves'], min_child_samples=best_trial.params['min_child_samples'], random_state=42)

best_model.fit(train_vectors, y_train)
y_pred = best_model.predict(test_vectors)
score = f1_score(y_test, y_pred)

print(f'Validation f1_score with the best model: {score}')
# Out:
# [I 2024-06-27 20:07:22,069] A new study created in memory with name: no-name-9fd4a4cd-b9af-4ed7-b63a-4c9ebc82bfd0
# [I 2024-06-27 20:07:22,100] Trial 1 finished with value: 0.6376811594202898 and parameters: {'classifier': 'SVC', 'C': 0.005958728140017298, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 1 with value: 0.6376811594202898.
# [I 2024-06-27 20:07:22,332] Trial 5 finished with value: 0.46153846153846156 and parameters: {'classifier': 'SVC', 'C': 2.1616717576024977, 'kernel': 'poly', 'gamma': 'auto'}. Best is trial 1 with value: 0.6376811594202898.
# [I 2024-06-27 20:07:22,335] Trial 4 finished with value: 0.6376811594202898 and parameters: {'classifier': 'LogisticRegression', 'C': 0.002941945513987425, 'solver': 'liblinear'}. Best is trial 1 with value: 0.6376811594202898.
# [I 2024-06-27 20:07:22,449] Trial 3 finished with value: 0.6222222222222222 and parameters: {'classifier': 'LogisticRegression', 'C': 0.41462203166233025, 'solver': 'sag'}. Best is trial 1 with value: 0.6376811594202898.
# [I 2024-06-27 20:07:22,458] Trial 8 finished with value: 0.5714285714285714 and parameters: {'classifier': 'SVC', 'C': 61.81509682718527, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 1 with value: 0.6376811594202898.
# [I 2024-06-27 20:07:22,506] Trial 11 finished with value: 0.6376811594202898 and parameters: {'classifier': 'SVC', 'C': 0.015240647530747498, 'kernel': 'sigmoid', 'gamma': 'scale'}. Best is trial 1 with value: 0.6376811594202898.
# [I 2024-06-27 20:07:22,533] Trial 12 finished with value: 0.5555555555555556 and parameters: {'classifier': 'LogisticRegression', 'C': 0.014767044549223835, 'solver': 'liblinear'}. Best is trial 1 with value: 0.6376811594202898.
# [I 2024-06-27 20:07:22,544] Trial 10 finished with value: 0.6376811594202898 and parameters: {'classifier': 'LogisticRegression', 'C': 0.00018016142563321338, 'solver': 'newton-cg'}. Best is trial 1 with value: 0.6376811594202898.
# [I 2024-06-27 20:07:22,585] Trial 14 finished with value: 0.6376811594202898 and parameters: {'classifier': 'SVC', 'C': 0.007311645022100981, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 1 with value: 0.6376811594202898.
# [I 2024-06-27 20:07:22,617] Trial 16 finished with value: 0.6376811594202898 and parameters: {'classifier': 'SVC', 'C': 0.002536509671718188, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 1 with value: 0.6376811594202898.
# [I 2024-06-27 20:07:22,876] Trial 2 finished with value: 0.6363636363636364 and parameters: {'classifier': 'XGBoost', 'n_estimators': 95, 'learning_rate': 0.2984395869304836, 'max_depth': 10, 'subsample': 0.712258105537461, 'colsample_bytree': 0.7285180907148726}. Best is trial 1 with value: 0.6376811594202898.
# [I 2024-06-27 20:07:23,698] Trial 15 finished with value: 0.5714285714285714 and parameters: {'classifier': 'LightGBM', 'n_estimators': 606, 'learning_rate': 0.24336459960938905, 'max_depth': 4, 'num_leaves': 148, 'min_child_samples': 19}. Best is trial 1 with value: 0.6376811594202898.
# [I 2024-06-27 20:07:24,592] Trial 17 finished with value: 0.6382978723404256 and parameters: {'classifier': 'LightGBM', 'n_estimators': 684, 'learning_rate': 0.2402578496112849, 'max_depth': 17, 'num_leaves': 2384, 'min_child_samples': 42}. Best is trial 17 with value: 0.6382978723404256.
# [I 2024-06-27 20:07:25,264] Trial 18 finished with value: 0.6376811594202898 and parameters: {'classifier': 'LightGBM', 'n_estimators': 985, 'learning_rate': 0.0483260287912675, 'max_depth': 2, 'num_leaves': 25, 'min_child_samples': 77}. Best is trial 17 with value: 0.6382978723404256.
# [I 2024-06-27 20:07:26,178] Trial 9 finished with value: 0.6363636363636364 and parameters: {'classifier': 'XGBoost', 'n_estimators': 783, 'learning_rate': 0.2279802352251194, 'max_depth': 28, 'subsample': 0.934317562289983, 'colsample_bytree': 0.8690781193802088}. Best is trial 17 with value: 0.6382978723404256.
# [I 2024-06-27 20:07:26,832] Trial 6 finished with value: 0.7111111111111111 and parameters: {'classifier': 'XGBoost', 'n_estimators': 923, 'learning_rate': 0.2800306064835882, 'max_depth': 9, 'subsample': 0.8878576185507592, 'colsample_bytree': 0.7575064832931651}. Best is trial 6 with value: 0.7111111111111111.
# [I 2024-06-27 20:07:27,990] Trial 13 finished with value: 0.6666666666666666 and parameters: {'classifier': 'XGBoost', 'n_estimators': 858, 'learning_rate': 0.29474891373552276, 'max_depth': 2, 'subsample': 0.633988934307285, 'colsample_bytree': 0.5641476006553314}. Best is trial 6 with value: 0.7111111111111111.
# [I 2024-06-27 20:07:30,723] Trial 7 finished with value: 0.6086956521739131 and parameters: {'classifier': 'RandomForest', 'n_estimators': 700, 'max_depth': 28, 'min_samples_split': 8, 'min_samples_leaf': 15}. Best is trial 6 with value: 0.7111111111111111.
# [I 2024-06-27 20:07:31,156] Trial 0 finished with value: 0.6666666666666666 and parameters: {'classifier': 'XGBoost', 'n_estimators': 926, 'learning_rate': 0.0358322282752219, 'max_depth': 5, 'subsample': 0.8678690624374041, 'colsample_bytree': 0.6821885047411509}. Best is trial 6 with value: 0.7111111111111111.
# [I 2024-06-27 20:07:31,653] Trial 22 finished with value: 0.6122448979591837 and parameters: {'classifier': 'RandomForest', 'n_estimators': 289, 'max_depth': 21, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 6 with value: 0.7111111111111111.
# [I 2024-06-27 20:07:33,903] Trial 26 finished with value: 0.6222222222222222 and parameters: {'classifier': 'XGBoost', 'n_estimators': 369, 'learning_rate': 0.012127076919416252, 'max_depth': 5, 'subsample': 0.9300159439944591, 'colsample_bytree': 0.6866816859329958}. Best is trial 6 with value: 0.7111111111111111.
# [I 2024-06-27 20:07:35,245] Trial 21 finished with value: 0.6363636363636364 and parameters: {'classifier': 'RandomForest', 'n_estimators': 669, 'max_depth': 27, 'min_samples_split': 11, 'min_samples_leaf': 9}. Best is trial 6 with value: 0.7111111111111111.
# [I 2024-06-27 20:07:35,995] Trial 25 finished with value: 0.6086956521739131 and parameters: {'classifier': 'XGBoost', 'n_estimators': 992, 'learning_rate': 0.2969879610538256, 'max_depth': 5, 'subsample': 0.5223728660161497, 'colsample_bytree': 0.5164094591639283}. Best is trial 6 with value: 0.7111111111111111.
# [I 2024-06-27 20:07:36,709] Trial 27 finished with value: 0.6521739130434783 and parameters: {'classifier': 'XGBoost', 'n_estimators': 966, 'learning_rate': 0.024387806089388925, 'max_depth': 6, 'subsample': 0.9037144020025221, 'colsample_bytree': 0.6840682090807918}. Best is trial 6 with value: 0.7111111111111111.
# [I 2024-06-27 20:07:37,288] Trial 19 finished with value: 0.6521739130434783 and parameters: {'classifier': 'RandomForest', 'n_estimators': 979, 'max_depth': 26, 'min_samples_split': 17, 'min_samples_leaf': 4}. Best is trial 6 with value: 0.7111111111111111.
# [I 2024-06-27 20:07:37,528] Trial 20 finished with value: 0.5957446808510638 and parameters: {'classifier': 'RandomForest', 'n_estimators': 967, 'max_depth': 30, 'min_samples_split': 10, 'min_samples_leaf': 16}. Best is trial 6 with value: 0.7111111111111111.
# [I 2024-06-27 20:07:37,627] Trial 23 finished with value: 0.6521739130434783 and parameters: {'classifier': 'RandomForest', 'n_estimators': 858, 'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 5}. Best is trial 6 with value: 0.7111111111111111.
# [I 2024-06-27 20:07:37,724] Trial 28 finished with value: 0.6222222222222222 and parameters: {'classifier': 'XGBoost', 'n_estimators': 992, 'learning_rate': 0.11146948800002213, 'max_depth': 2, 'subsample': 0.5186701584861833, 'colsample_bytree': 0.5186551719133301}. Best is trial 6 with value: 0.7111111111111111.
# [I 2024-06-27 20:07:38,125] Trial 24 finished with value: 0.6521739130434783 and parameters: {'classifier': 'RandomForest', 'n_estimators': 984, 'max_depth': 5, 'min_samples_split': 16, 'min_samples_leaf': 1}. Best is trial 6 with value: 0.7111111111111111.
# [I 2024-06-27 20:07:38,265] Trial 29 finished with value: 0.625 and parameters: {'classifier': 'XGBoost', 'n_estimators': 984, 'learning_rate': 0.11055698746947012, 'max_depth': 2, 'subsample': 0.5132745045621716, 'colsample_bytree': 0.5049107809960512}. Best is trial 6 with value: 0.7111111111111111.
# [I 2024-06-27 20:07:38,398] Trial 30 finished with value: 0.5909090909090909 and parameters: {'classifier': 'XGBoost', 'n_estimators': 855, 'learning_rate': 0.10601154803144419, 'max_depth': 10, 'subsample': 0.7987099622553189, 'colsample_bytree': 0.573537544382657}. Best is trial 6 with value: 0.7111111111111111.
# [I 2024-06-27 20:07:38,577] Trial 31 finished with value: 0.6521739130434783 and parameters: {'classifier': 'XGBoost', 'n_estimators': 863, 'learning_rate': 0.12788730650128258, 'max_depth': 2, 'subsample': 0.7725227156726483, 'colsample_bytree': 0.533764899883188}. Best is trial 6 with value: 0.7111111111111111.
# [I 2024-06-27 20:07:38,783] Trial 32 finished with value: 0.6521739130434783 and parameters: {'classifier': 'XGBoost', 'n_estimators': 827, 'learning_rate': 0.16607167842792586, 'max_depth': 2, 'subsample': 0.7654732935512646, 'colsample_bytree': 0.520956888630586}. Best is trial 6 with value: 0.7111111111111111.
# [I 2024-06-27 20:07:38,939] Trial 35 finished with value: 0.6666666666666666 and parameters: {'classifier': 'XGBoost', 'n_estimators': 825, 'learning_rate': 0.16136529919422204, 'max_depth': 3, 'subsample': 0.7839069508340323, 'colsample_bytree': 0.8407697586668119}. Best is trial 6 with value: 0.7111111111111111.
# [I 2024-06-27 20:07:39,007] Trial 33 finished with value: 0.6666666666666666 and parameters: {'classifier': 'XGBoost', 'n_estimators': 821, 'learning_rate': 0.11652436730413074, 'max_depth': 2, 'subsample': 0.7692902311062909, 'colsample_bytree': 0.5298082705029804}. Best is trial 6 with value: 0.7111111111111111.
# [I 2024-06-27 20:07:39,084] Trial 34 finished with value: 0.6818181818181818 and parameters: {'classifier': 'XGBoost', 'n_estimators': 831, 'learning_rate': 0.11107491633116409, 'max_depth': 2, 'subsample': 0.7655740032319679, 'colsample_bytree': 0.5443666164139028}. Best is trial 6 with value: 0.7111111111111111.
# [I 2024-06-27 20:07:39,362] Trial 36 finished with value: 0.6976744186046512 and parameters: {'classifier': 'XGBoost', 'n_estimators': 830, 'learning_rate': 0.15174258246379738, 'max_depth': 3, 'subsample': 0.7843291362864296, 'colsample_bytree': 0.8288751309249346}. Best is trial 6 with value: 0.7111111111111111.
# [I 2024-06-27 20:07:39,492] Trial 37 finished with value: 0.6956521739130435 and parameters: {'classifier': 'XGBoost', 'n_estimators': 849, 'learning_rate': 0.18679908102904041, 'max_depth': 3, 'subsample': 0.7696954246781826, 'colsample_bytree': 0.8300910838323114}. Best is trial 6 with value: 0.7111111111111111.
# [I 2024-06-27 20:07:39,639] Trial 38 finished with value: 0.6666666666666666 and parameters: {'classifier': 'XGBoost', 'n_estimators': 844, 'learning_rate': 0.17135089992327504, 'max_depth': 3, 'subsample': 0.8001940222144228, 'colsample_bytree': 0.8272412368769184}. Best is trial 6 with value: 0.7111111111111111.
# [I 2024-06-27 20:07:39,791] Trial 39 finished with value: 0.6666666666666666 and parameters: {'classifier': 'XGBoost', 'n_estimators': 837, 'learning_rate': 0.20008626589563597, 'max_depth': 3, 'subsample': 0.6465759513535204, 'colsample_bytree': 0.8274995438349722}. Best is trial 6 with value: 0.7111111111111111.
# [I 2024-06-27 20:07:39,972] Trial 40 finished with value: 0.6511627906976745 and parameters: {'classifier': 'XGBoost', 'n_estimators': 783, 'learning_rate': 0.19399361480401955, 'max_depth': 3, 'subsample': 0.6459437997206042, 'colsample_bytree': 0.8581264442606594}. Best is trial 6 with value: 0.7111111111111111.
# [I 2024-06-27 20:07:40,200] Trial 41 finished with value: 0.6046511627906976 and parameters: {'classifier': 'XGBoost', 'n_estimators': 785, 'learning_rate': 0.1986001105517644, 'max_depth': 3, 'subsample': 0.8677430383667217, 'colsample_bytree': 0.8399522996632666}. Best is trial 6 with value: 0.7111111111111111.
# [I 2024-06-27 20:07:40,236] Trial 49 finished with value: 0.6376811594202898 and parameters: {'classifier': 'LogisticRegression', 'C': 1.324344729527994e-05, 'solver': 'lbfgs'}. Best is trial 6 with value: 0.7111111111111111.
# [I 2024-06-27 20:07:40,501] Trial 46 finished with value: 0.6666666666666666 and parameters: {'classifier': 'XGBoost', 'n_estimators': 498, 'learning_rate': 0.19004082202528375, 'max_depth': 3, 'subsample': 0.9941927003622972, 'colsample_bytree': 0.9635071127277522}. Best is trial 6 with value: 0.7111111111111111.
# [I 2024-06-27 20:07:40,512] Trial 42 finished with value: 0.6511627906976745 and parameters: {'classifier': 'XGBoost', 'n_estimators': 740, 'learning_rate': 0.061905164991471695, 'max_depth': 3, 'subsample': 0.6561455744255855, 'colsample_bytree': 0.6167540308874268}. Best is trial 6 with value: 0.7111111111111111.
# [I 2024-06-27 20:07:40,598] Trial 43 finished with value: 0.6511627906976745 and parameters: {'classifier': 'XGBoost', 'n_estimators': 749, 'learning_rate': 0.06008506828324067, 'max_depth': 3, 'subsample': 0.6676097422484488, 'colsample_bytree': 0.6190477724309522}. Best is trial 6 with value: 0.7111111111111111.
# [I 2024-06-27 20:07:40,708] Trial 45 finished with value: 0.7142857142857143 and parameters: {'classifier': 'XGBoost', 'n_estimators': 750, 'learning_rate': 0.20246739222962115, 'max_depth': 3, 'subsample': 0.8479338507394775, 'colsample_bytree': 0.8065041077436261}. Best is trial 45 with value: 0.7142857142857143.
# c:\Users\user\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2024-06-27 20:07:40,851] Trial 53 finished with value: 0.5789473684210527 and parameters: {'classifier': 'LogisticRegression', 'C': 85.25558344435858, 'solver': 'saga'}. Best is trial 45 with value: 0.7142857142857143.
# c:\Users\user\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2024-06-27 20:07:40,923] Trial 54 finished with value: 0.5945945945945946 and parameters: {'classifier': 'LogisticRegression', 'C': 67.0356419843476, 'solver': 'saga'}. Best is trial 45 with value: 0.7142857142857143.
# [I 2024-06-27 20:07:40,991] Trial 44 finished with value: 0.6956521739130435 and parameters: {'classifier': 'XGBoost', 'n_estimators': 750, 'learning_rate': 0.06912952867431289, 'max_depth': 3, 'subsample': 0.8644673737238588, 'colsample_bytree': 0.7874766987521808}. Best is trial 45 with value: 0.7142857142857143.
# [I 2024-06-27 20:07:40,994] Trial 47 finished with value: 0.6666666666666666 and parameters: {'classifier': 'XGBoost', 'n_estimators': 741, 'learning_rate': 0.19850471137349782, 'max_depth': 8, 'subsample': 0.8520713146667691, 'colsample_bytree': 0.9667620731949431}. Best is trial 45 with value: 0.7142857142857143.
# [I 2024-06-27 20:07:41,652] Trial 56 finished with value: 0.6376811594202898 and parameters: {'classifier': 'LightGBM', 'n_estimators': 907, 'learning_rate': 0.14350858387362012, 'max_depth': 9, 'num_leaves': 1372, 'min_child_samples': 86}. Best is trial 45 with value: 0.7142857142857143.
# [I 2024-06-27 20:07:41,748] Trial 48 finished with value: 0.6818181818181818 and parameters: {'classifier': 'XGBoost', 'n_estimators': 740, 'learning_rate': 0.0534264646368066, 'max_depth': 8, 'subsample': 0.8630465731874118, 'colsample_bytree': 0.926698555549287}. Best is trial 45 with value: 0.7142857142857143.
# [I 2024-06-27 20:07:41,778] Trial 60 finished with value: 0.3225806451612903 and parameters: {'classifier': 'SVC', 'C': 0.46158780834128876, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 45 with value: 0.7142857142857143.
# [I 2024-06-27 20:07:42,099] Trial 50 finished with value: 0.6818181818181818 and parameters: {'classifier': 'XGBoost', 'n_estimators': 909, 'learning_rate': 0.07676138139626967, 'max_depth': 7, 'subsample': 0.8470741661614204, 'colsample_bytree': 0.764696767834996}. Best is trial 45 with value: 0.7142857142857143.
# [I 2024-06-27 20:07:42,356] Trial 52 finished with value: 0.6666666666666666 and parameters: {'classifier': 'XGBoost', 'n_estimators': 909, 'learning_rate': 0.0874685353990908, 'max_depth': 8, 'subsample': 0.8378431082839047, 'colsample_bytree': 0.7720839384833502}. Best is trial 45 with value: 0.7142857142857143.
# [I 2024-06-27 20:07:42,462] Trial 55 finished with value: 0.6829268292682927 and parameters: {'classifier': 'XGBoost', 'n_estimators': 897, 'learning_rate': 0.1368191106324769, 'max_depth': 8, 'subsample': 0.8328547303150771, 'colsample_bytree': 0.779234972800875}. Best is trial 45 with value: 0.7142857142857143.
# [I 2024-06-27 20:07:42,538] Trial 51 finished with value: 0.6363636363636364 and parameters: {'classifier': 'XGBoost', 'n_estimators': 911, 'learning_rate': 0.07360729936578658, 'max_depth': 9, 'subsample': 0.8367625658713873, 'colsample_bytree': 0.7640254406388687}. Best is trial 45 with value: 0.7142857142857143.
# [I 2024-06-27 20:07:42,616] Trial 58 finished with value: 0.6363636363636364 and parameters: {'classifier': 'XGBoost', 'n_estimators': 915, 'learning_rate': 0.14122933866133222, 'max_depth': 4, 'subsample': 0.8309574011094185, 'colsample_bytree': 0.7803630185426456}. Best is trial 45 with value: 0.7142857142857143.
# [I 2024-06-27 20:07:42,846] Trial 57 finished with value: 0.6521739130434783 and parameters: {'classifier': 'XGBoost', 'n_estimators': 918, 'learning_rate': 0.08553733092466503, 'max_depth': 4, 'subsample': 0.8268547518035684, 'colsample_bytree': 0.777180406525837}. Best is trial 45 with value: 0.7142857142857143.
# [I 2024-06-27 20:07:42,921] Trial 59 finished with value: 0.6363636363636364 and parameters: {'classifier': 'XGBoost', 'n_estimators': 610, 'learning_rate': 0.14192807466141424, 'max_depth': 4, 'subsample': 0.8451726987228283, 'colsample_bytree': 0.7804433047567902}. Best is trial 45 with value: 0.7142857142857143.
# [I 2024-06-27 20:07:43,244] Trial 63 finished with value: 0.6666666666666666 and parameters: {'classifier': 'XGBoost', 'n_estimators': 630, 'learning_rate': 0.26882307559737106, 'max_depth': 4, 'subsample': 0.8249092577820325, 'colsample_bytree': 0.7942651420358731}. Best is trial 45 with value: 0.7142857142857143.
# [I 2024-06-27 20:07:43,294] Trial 62 finished with value: 0.6382978723404256 and parameters: {'classifier': 'XGBoost', 'n_estimators': 588, 'learning_rate': 0.08645134477902953, 'max_depth': 4, 'subsample': 0.7304111609823737, 'colsample_bytree': 0.773463242044872}. Best is trial 45 with value: 0.7142857142857143.
# [I 2024-06-27 20:07:43,486] Trial 61 finished with value: 0.7272727272727273 and parameters: {'classifier': 'XGBoost', 'n_estimators': 909, 'learning_rate': 0.0797486308939134, 'max_depth': 4, 'subsample': 0.8202196422366682, 'colsample_bytree': 0.778440540834797}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:07:44,463] Trial 64 finished with value: 0.6818181818181818 and parameters: {'classifier': 'LightGBM', 'n_estimators': 643, 'learning_rate': 0.14217967664143283, 'max_depth': 4, 'num_leaves': 23, 'min_child_samples': 12}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:07:44,487] Trial 72 finished with value: 0.6376811594202898 and parameters: {'classifier': 'SVC', 'C': 1.0220519224333778e-05, 'kernel': 'poly', 'gamma': 'auto'}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:07:44,596] Trial 65 finished with value: 0.6222222222222222 and parameters: {'classifier': 'LightGBM', 'n_estimators': 613, 'learning_rate': 0.14154397996009527, 'max_depth': 4, 'num_leaves': 219, 'min_child_samples': 5}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:07:44,655] Trial 66 finished with value: 0.6511627906976745 and parameters: {'classifier': 'LightGBM', 'n_estimators': 625, 'learning_rate': 0.27076519221609946, 'max_depth': 4, 'num_leaves': 22, 'min_child_samples': 11}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:07:44,948] Trial 70 finished with value: 0.6341463414634146 and parameters: {'classifier': 'LightGBM', 'n_estimators': 715, 'learning_rate': 0.22636938900368542, 'max_depth': 7, 'num_leaves': 23, 'min_child_samples': 7}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:07:45,115] Trial 67 finished with value: 0.5909090909090909 and parameters: {'classifier': 'LightGBM', 'n_estimators': 621, 'learning_rate': 0.25745350580500204, 'max_depth': 13, 'num_leaves': 207, 'min_child_samples': 9}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:07:45,213] Trial 68 finished with value: 0.6382978723404256 and parameters: {'classifier': 'LightGBM', 'n_estimators': 631, 'learning_rate': 0.26735789386214226, 'max_depth': 13, 'num_leaves': 22, 'min_child_samples': 9}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:07:45,407] Trial 69 finished with value: 0.6222222222222222 and parameters: {'classifier': 'LightGBM', 'n_estimators': 676, 'learning_rate': 0.22067838750480712, 'max_depth': 13, 'num_leaves': 20, 'min_child_samples': 5}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:07:45,497] Trial 71 finished with value: 0.6382978723404256 and parameters: {'classifier': 'LightGBM', 'n_estimators': 695, 'learning_rate': 0.22061204072333815, 'max_depth': 12, 'num_leaves': 27, 'min_child_samples': 5}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:07:45,585] Trial 78 finished with value: 0.5454545454545454 and parameters: {'classifier': 'XGBoost', 'n_estimators': 62, 'learning_rate': 0.09695004245151274, 'max_depth': 11, 'subsample': 0.889625403794837, 'colsample_bytree': 0.72703578183461}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:07:45,819] Trial 75 finished with value: 0.6363636363636364 and parameters: {'classifier': 'XGBoost', 'n_estimators': 706, 'learning_rate': 0.22176696292658804, 'max_depth': 13, 'subsample': 0.908655145617886, 'colsample_bytree': 0.7165717627484207}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:07:45,851] Trial 74 finished with value: 0.6122448979591837 and parameters: {'classifier': 'XGBoost', 'n_estimators': 705, 'learning_rate': 0.222726800021884, 'max_depth': 12, 'subsample': 0.8974248779206275, 'colsample_bytree': 0.7269092945165225}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:07:45,960] Trial 80 finished with value: 0.5581395348837209 and parameters: {'classifier': 'XGBoost', 'n_estimators': 83, 'learning_rate': 0.17692442509443124, 'max_depth': 6, 'subsample': 0.9101096845804398, 'colsample_bytree': 0.7284602810292444}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:07:46,035] Trial 73 finished with value: 0.6086956521739131 and parameters: {'classifier': 'XGBoost', 'n_estimators': 877, 'learning_rate': 0.2155065046328646, 'max_depth': 13, 'subsample': 0.8945763854423097, 'colsample_bytree': 0.7255453392299386}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:07:46,456] Trial 77 finished with value: 0.6666666666666666 and parameters: {'classifier': 'XGBoost', 'n_estimators': 787, 'learning_rate': 0.21535795735892405, 'max_depth': 6, 'subsample': 0.8928900069812545, 'colsample_bytree': 0.7343406279751312}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:07:47,263] Trial 76 finished with value: 0.6222222222222222 and parameters: {'classifier': 'XGBoost', 'n_estimators': 944, 'learning_rate': 0.17679669136372228, 'max_depth': 11, 'subsample': 0.9013923697958705, 'colsample_bytree': 0.7224907755068004}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:07:48,533] Trial 79 finished with value: 0.6666666666666666 and parameters: {'classifier': 'XGBoost', 'n_estimators': 787, 'learning_rate': 0.09949247059781446, 'max_depth': 6, 'subsample': 0.8903086429030679, 'colsample_bytree': 0.7211948394114328}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:07:48,672] Trial 81 finished with value: 0.5833333333333334 and parameters: {'classifier': 'XGBoost', 'n_estimators': 877, 'learning_rate': 0.17981815006868945, 'max_depth': 6, 'subsample': 0.731354881996267, 'colsample_bytree': 0.736210329667327}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:07:49,282] Trial 83 finished with value: 0.7083333333333334 and parameters: {'classifier': 'XGBoost', 'n_estimators': 793, 'learning_rate': 0.12439338974041209, 'max_depth': 5, 'subsample': 0.7344878464384832, 'colsample_bytree': 0.809575330921742}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:07:49,354] Trial 85 finished with value: 0.6521739130434783 and parameters: {'classifier': 'XGBoost', 'n_estimators': 803, 'learning_rate': 0.12183966783617575, 'max_depth': 6, 'subsample': 0.7360042414768729, 'colsample_bytree': 0.8039391559745033}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:07:50,321] Trial 82 finished with value: 0.6976744186046512 and parameters: {'classifier': 'XGBoost', 'n_estimators': 872, 'learning_rate': 0.11966925787977023, 'max_depth': 6, 'subsample': 0.7039860317733646, 'colsample_bytree': 0.803631242389911}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:07:51,737] Trial 84 finished with value: 0.6382978723404256 and parameters: {'classifier': 'XGBoost', 'n_estimators': 950, 'learning_rate': 0.11952499639825057, 'max_depth': 6, 'subsample': 0.7022427531234139, 'colsample_bytree': 0.8119699698257198}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:07:58,634] Trial 88 finished with value: 0.6818181818181818 and parameters: {'classifier': 'XGBoost', 'n_estimators': 878, 'learning_rate': 0.052363580352746, 'max_depth': 8, 'subsample': 0.7314911908125996, 'colsample_bytree': 0.9231095136249282}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:07:59,266] Trial 87 finished with value: 0.5333333333333333 and parameters: {'classifier': 'RandomForest', 'n_estimators': 878, 'max_depth': 16, 'min_samples_split': 2, 'min_samples_leaf': 20}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:07:59,494] Trial 95 finished with value: 0.6376811594202898 and parameters: {'classifier': 'SVC', 'C': 0.00025348485956551073, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:08:00,292] Trial 89 finished with value: 0.6511627906976745 and parameters: {'classifier': 'XGBoost', 'n_estimators': 953, 'learning_rate': 0.03984345977572797, 'max_depth': 8, 'subsample': 0.8013416189528578, 'colsample_bytree': 0.9115521653346338}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:08:00,611] Trial 86 finished with value: 0.5 and parameters: {'classifier': 'RandomForest', 'n_estimators': 941, 'max_depth': 17, 'min_samples_split': 2, 'min_samples_leaf': 20}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:08:00,798] Trial 97 finished with value: 0.5238095238095238 and parameters: {'classifier': 'LogisticRegression', 'C': 4.968711684682966, 'solver': 'newton-cg'}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:08:01,757] Trial 94 finished with value: 0.5531914893617021 and parameters: {'classifier': 'RandomForest', 'n_estimators': 213, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 19}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:08:02,076] Trial 96 finished with value: 0.7111111111111111 and parameters: {'classifier': 'XGBoost', 'n_estimators': 321, 'learning_rate': 0.15055865775397193, 'max_depth': 5, 'subsample': 0.8008015120918452, 'colsample_bytree': 0.8715966298937475}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:08:02,572] Trial 91 finished with value: 0.5 and parameters: {'classifier': 'RandomForest', 'n_estimators': 942, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 20}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:08:02,720] Trial 92 finished with value: 0.5 and parameters: {'classifier': 'RandomForest', 'n_estimators': 941, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 20}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:08:02,937] Trial 90 finished with value: 0.5 and parameters: {'classifier': 'RandomForest', 'n_estimators': 951, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 20}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:08:02,949] Trial 93 finished with value: 0.5333333333333333 and parameters: {'classifier': 'RandomForest', 'n_estimators': 880, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 20}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:08:03,233] Trial 98 finished with value: 0.7111111111111111 and parameters: {'classifier': 'XGBoost', 'n_estimators': 815, 'learning_rate': 0.15498178144185976, 'max_depth': 5, 'subsample': 0.6967181639531331, 'colsample_bytree': 0.8124701935329374}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:08:03,315] Trial 99 finished with value: 0.6190476190476191 and parameters: {'classifier': 'XGBoost', 'n_estimators': 827, 'learning_rate': 0.15814745728747323, 'max_depth': 5, 'subsample': 0.7007574166343099, 'colsample_bytree': 0.8642679607828849}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:08:03,467] Trial 101 finished with value: 0.6976744186046512 and parameters: {'classifier': 'XGBoost', 'n_estimators': 546, 'learning_rate': 0.1564310971403911, 'max_depth': 5, 'subsample': 0.6989472394165442, 'colsample_bytree': 0.8802996495451298}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:08:03,627] Trial 100 finished with value: 0.6382978723404256 and parameters: {'classifier': 'XGBoost', 'n_estimators': 810, 'learning_rate': 0.15445339610883593, 'max_depth': 5, 'subsample': 0.7562418314679171, 'colsample_bytree': 0.8735427148576392}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:08:03,748] Trial 102 finished with value: 0.6222222222222222 and parameters: {'classifier': 'XGBoost', 'n_estimators': 384, 'learning_rate': 0.12700665968571564, 'max_depth': 5, 'subsample': 0.8076849136963133, 'colsample_bytree': 0.869110519465776}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:08:03,852] Trial 103 finished with value: 0.5652173913043478 and parameters: {'classifier': 'XGBoost', 'n_estimators': 428, 'learning_rate': 0.15450877602519802, 'max_depth': 9, 'subsample': 0.7028758896301527, 'colsample_bytree': 0.879255371683865}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:08:03,984] Trial 104 finished with value: 0.6190476190476191 and parameters: {'classifier': 'XGBoost', 'n_estimators': 457, 'learning_rate': 0.1556951593598593, 'max_depth': 7, 'subsample': 0.7003653132223582, 'colsample_bytree': 0.8922052164642748}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:08:04,008] Trial 105 finished with value: 0.6976744186046512 and parameters: {'classifier': 'XGBoost', 'n_estimators': 488, 'learning_rate': 0.1595859946183326, 'max_depth': 9, 'subsample': 0.6927011877412849, 'colsample_bytree': 0.8911373782614583}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:08:04,266] Trial 106 finished with value: 0.6222222222222222 and parameters: {'classifier': 'XGBoost', 'n_estimators': 463, 'learning_rate': 0.15346211326213785, 'max_depth': 7, 'subsample': 0.6983458242768654, 'colsample_bytree': 0.8816452383678852}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:08:04,366] Trial 107 finished with value: 0.7272727272727273 and parameters: {'classifier': 'XGBoost', 'n_estimators': 489, 'learning_rate': 0.15687101867883313, 'max_depth': 7, 'subsample': 0.6855677039011816, 'colsample_bytree': 0.8849683834540902}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:08:04,506] Trial 108 finished with value: 0.6976744186046512 and parameters: {'classifier': 'XGBoost', 'n_estimators': 490, 'learning_rate': 0.15808688671810284, 'max_depth': 7, 'subsample': 0.6886659549596176, 'colsample_bytree': 0.8904864910028378}. Best is trial 61 with value: 0.7272727272727273.
# [I 2024-06-27 20:08:04,629] Trial 109 finished with value: 0.7441860465116279 and parameters: {'classifier': 'XGBoost', 'n_estimators': 411, 'learning_rate': 0.12875636958411782, 'max_depth': 7, 'subsample': 0.6813570658815952, 'colsample_bytree': 0.8905441659227418}. Best is trial 109 with value: 0.7441860465116279.
# [I 2024-06-27 20:08:04,707] Trial 112 finished with value: 0.5909090909090909 and parameters: {'classifier': 'XGBoost', 'n_estimators': 246, 'learning_rate': 0.16758338998406574, 'max_depth': 3, 'subsample': 0.6124596602688301, 'colsample_bytree': 0.8200414948460953}. Best is trial 109 with value: 0.7441860465116279.
# [I 2024-06-27 20:08:04,783] Trial 110 finished with value: 0.6818181818181818 and parameters: {'classifier': 'XGBoost', 'n_estimators': 432, 'learning_rate': 0.1520550073477908, 'max_depth': 7, 'subsample': 0.6774800726510778, 'colsample_bytree': 0.8183686271324234}. Best is trial 109 with value: 0.7441860465116279.
# [I 2024-06-27 20:08:04,839] Trial 113 finished with value: 0.6666666666666666 and parameters: {'classifier': 'XGBoost', 'n_estimators': 258, 'learning_rate': 0.16427926368488904, 'max_depth': 9, 'subsample': 0.6800079482982038, 'colsample_bytree': 0.824774794613973}. Best is trial 109 with value: 0.7441860465116279.
# [I 2024-06-27 20:08:05,020] Trial 114 finished with value: 0.6666666666666666 and parameters: {'classifier': 'XGBoost', 'n_estimators': 208, 'learning_rate': 0.16701213376689888, 'max_depth': 10, 'subsample': 0.6663711306613468, 'colsample_bytree': 0.8424700209197012}. Best is trial 109 with value: 0.7441860465116279.
# [I 2024-06-27 20:08:05,264] Trial 111 finished with value: 0.6341463414634146 and parameters: {'classifier': 'XGBoost', 'n_estimators': 762, 'learning_rate': 0.16702413412626632, 'max_depth': 7, 'subsample': 0.6816176683417088, 'colsample_bytree': 0.8139869148402523}. Best is trial 109 with value: 0.7441860465116279.
# [I 2024-06-27 20:08:05,455] Trial 115 finished with value: 0.6511627906976745 and parameters: {'classifier': 'XGBoost', 'n_estimators': 552, 'learning_rate': 0.16694345228512328, 'max_depth': 23, 'subsample': 0.6777113657112688, 'colsample_bytree': 0.8145779521261138}. Best is trial 109 with value: 0.7441860465116279.
# [I 2024-06-27 20:08:05,603] Trial 116 finished with value: 0.6086956521739131 and parameters: {'classifier': 'XGBoost', 'n_estimators': 533, 'learning_rate': 0.13168662048168628, 'max_depth': 10, 'subsample': 0.6768374888894656, 'colsample_bytree': 0.8474108339877024}. Best is trial 109 with value: 0.7441860465116279.
# [I 2024-06-27 20:08:05,811] Trial 117 finished with value: 0.6666666666666666 and parameters: {'classifier': 'XGBoost', 'n_estimators': 568, 'learning_rate': 0.13154969862066476, 'max_depth': 10, 'subsample': 0.673122753031419, 'colsample_bytree': 0.8457102779065528}. Best is trial 109 with value: 0.7441860465116279.
# [I 2024-06-27 20:08:05,867] Trial 120 finished with value: 0.6666666666666666 and parameters: {'classifier': 'XGBoost', 'n_estimators': 554, 'learning_rate': 0.13560927691592273, 'max_depth': 10, 'subsample': 0.7181778552855538, 'colsample_bytree': 0.849418574124475}. Best is trial 109 with value: 0.7441860465116279.
# [I 2024-06-27 20:08:05,924] Trial 118 finished with value: 0.6666666666666666 and parameters: {'classifier': 'XGBoost', 'n_estimators': 565, 'learning_rate': 0.13384843059284554, 'max_depth': 10, 'subsample': 0.6711268945039529, 'colsample_bytree': 0.84768354860655}. Best is trial 109 with value: 0.7441860465116279.
# [I 2024-06-27 20:08:05,937] Trial 119 finished with value: 0.6382978723404256 and parameters: {'classifier': 'XGBoost', 'n_estimators': 547, 'learning_rate': 0.13187136230578694, 'max_depth': 10, 'subsample': 0.6739379836339037, 'colsample_bytree': 0.846231532088614}. Best is trial 109 with value: 0.7441860465116279.
# [I 2024-06-27 20:08:06,002] Trial 126 finished with value: 0.5909090909090909 and parameters: {'classifier': 'LogisticRegression', 'C': 0.12786782058170182, 'solver': 'sag'}. Best is trial 109 with value: 0.7441860465116279.
# [I 2024-06-27 20:08:06,084] Trial 127 finished with value: 0.5777777777777777 and parameters: {'classifier': 'LogisticRegression', 'C': 0.1909115188879932, 'solver': 'lbfgs'}. Best is trial 109 with value: 0.7441860465116279.
# [I 2024-06-27 20:08:06,164] Trial 121 finished with value: 0.6521739130434783 and parameters: {'classifier': 'XGBoost', 'n_estimators': 533, 'learning_rate': 0.12629656629474215, 'max_depth': 10, 'subsample': 0.6255048451407701, 'colsample_bytree': 0.8447209599709373}. Best is trial 109 with value: 0.7441860465116279.
# [I 2024-06-27 20:08:06,428] Trial 123 finished with value: 0.723404255319149 and parameters: {'classifier': 'XGBoost', 'n_estimators': 318, 'learning_rate': 0.13239308599667654, 'max_depth': 11, 'subsample': 0.7841611736932815, 'colsample_bytree': 0.8524846084508196}. Best is trial 109 with value: 0.7441860465116279.
# [I 2024-06-27 20:08:06,517] Trial 122 finished with value: 0.6666666666666666 and parameters: {'classifier': 'XGBoost', 'n_estimators': 526, 'learning_rate': 0.13232635504194115, 'max_depth': 10, 'subsample': 0.6189256682083724, 'colsample_bytree': 0.8504745582778412}. Best is trial 109 with value: 0.7441860465116279.
# [I 2024-06-27 20:08:06,552] Trial 133 finished with value: 0.6376811594202898 and parameters: {'classifier': 'SVC', 'C': 0.0004900870498718092, 'kernel': 'sigmoid', 'gamma': 'auto'}. Best is trial 109 with value: 0.7441860465116279.
# [I 2024-06-27 20:08:06,697] Trial 124 finished with value: 0.6666666666666666 and parameters: {'classifier': 'XGBoost', 'n_estimators': 377, 'learning_rate': 0.14820394848034396, 'max_depth': 9, 'subsample': 0.7173316134320736, 'colsample_bytree': 0.8973874703882513}. Best is trial 109 with value: 0.7441860465116279.
# [I 2024-06-27 20:08:06,828] Trial 125 finished with value: 0.7142857142857143 and parameters: {'classifier': 'XGBoost', 'n_estimators': 325, 'learning_rate': 0.2877231272349029, 'max_depth': 9, 'subsample': 0.6100577340653133, 'colsample_bytree': 0.9022790257568707}. Best is trial 109 with value: 0.7441860465116279.
# [I 2024-06-27 20:08:07,089] Trial 131 finished with value: 0.6363636363636364 and parameters: {'classifier': 'XGBoost', 'n_estimators': 502, 'learning_rate': 0.23839301274270083, 'max_depth': 8, 'subsample': 0.7773953031273785, 'colsample_bytree': 0.8920575693202564}. Best is trial 109 with value: 0.7441860465116279.
# [I 2024-06-27 20:08:07,197] Trial 129 finished with value: 0.6666666666666666 and parameters: {'classifier': 'XGBoost', 'n_estimators': 498, 'learning_rate': 0.14860517502566267, 'max_depth': 9, 'subsample': 0.6183662639078187, 'colsample_bytree': 0.8983208319974006}. Best is trial 109 with value: 0.7441860465116279.
# [I 2024-06-27 20:08:07,271] Trial 130 finished with value: 0.6382978723404256 and parameters: {'classifier': 'XGBoost', 'n_estimators': 500, 'learning_rate': 0.14711801662490084, 'max_depth': 9, 'subsample': 0.7168443747981453, 'colsample_bytree': 0.8957832677593653}. Best is trial 109 with value: 0.7441860465116279.
# [I 2024-06-27 20:08:07,308] Trial 128 finished with value: 0.7727272727272727 and parameters: {'classifier': 'XGBoost', 'n_estimators': 500, 'learning_rate': 0.14745256133208134, 'max_depth': 9, 'subsample': 0.7855317023565338, 'colsample_bytree': 0.9153826528006682}. Best is trial 128 with value: 0.7727272727272727.
# [I 2024-06-27 20:08:07,480] Trial 135 finished with value: 0.6976744186046512 and parameters: {'classifier': 'XGBoost', 'n_estimators': 325, 'learning_rate': 0.28629968571174724, 'max_depth': 11, 'subsample': 0.79014754677572, 'colsample_bytree': 0.7541370699294081}. Best is trial 128 with value: 0.7727272727272727.
# [I 2024-06-27 20:08:07,543] Trial 132 finished with value: 0.6222222222222222 and parameters: {'classifier': 'XGBoost', 'n_estimators': 348, 'learning_rate': 0.11223230336489685, 'max_depth': 11, 'subsample': 0.8158984143789969, 'colsample_bytree': 0.9066147433861869}. Best is trial 128 with value: 0.7727272727272727.
# [I 2024-06-27 20:08:07,664] Trial 134 finished with value: 0.6976744186046512 and parameters: {'classifier': 'XGBoost', 'n_estimators': 340, 'learning_rate': 0.1023199617994383, 'max_depth': 11, 'subsample': 0.780803878038296, 'colsample_bytree': 0.7985210754034965}. Best is trial 128 with value: 0.7727272727272727.
# [I 2024-06-27 20:08:07,770] Trial 136 finished with value: 0.5853658536585366 and parameters: {'classifier': 'XGBoost', 'n_estimators': 344, 'learning_rate': 0.29108059422115606, 'max_depth': 11, 'subsample': 0.597336002496172, 'colsample_bytree': 0.7957962296535364}. Best is trial 128 with value: 0.7727272727272727.
# [I 2024-06-27 20:08:08,009] Trial 137 finished with value: 0.5454545454545454 and parameters: {'classifier': 'XGBoost', 'n_estimators': 326, 'learning_rate': 0.2873770752995567, 'max_depth': 11, 'subsample': 0.5853378673796461, 'colsample_bytree': 0.7549369029780701}. Best is trial 128 with value: 0.7727272727272727.
# [I 2024-06-27 20:08:08,174] Trial 139 finished with value: 0.5333333333333333 and parameters: {'classifier': 'XGBoost', 'n_estimators': 311, 'learning_rate': 0.29575462980700845, 'max_depth': 11, 'subsample': 0.586182097423857, 'colsample_bytree': 0.9435832294036334}. Best is trial 128 with value: 0.7727272727272727.
# [I 2024-06-27 20:08:08,287] Trial 140 finished with value: 0.55 and parameters: {'classifier': 'XGBoost', 'n_estimators': 345, 'learning_rate': 0.2825951419483104, 'max_depth': 12, 'subsample': 0.5657613129495949, 'colsample_bytree': 0.936992734592627}. Best is trial 128 with value: 0.7727272727272727.
# [I 2024-06-27 20:08:08,345] Trial 143 finished with value: 0.5238095238095238 and parameters: {'classifier': 'XGBoost', 'n_estimators': 287, 'learning_rate': 0.2840332888446335, 'max_depth': 32, 'subsample': 0.5861379999423149, 'colsample_bytree': 0.9224498139483959}. Best is trial 128 with value: 0.7727272727272727.
# [I 2024-06-27 20:08:08,349] Trial 142 finished with value: 0.6046511627906976 and parameters: {'classifier': 'XGBoost', 'n_estimators': 306, 'learning_rate': 0.28397946968116455, 'max_depth': 6, 'subsample': 0.5946052417252756, 'colsample_bytree': 0.9490465261471531}. Best is trial 128 with value: 0.7727272727272727.
# [I 2024-06-27 20:08:08,351] Trial 141 finished with value: 0.6222222222222222 and parameters: {'classifier': 'XGBoost', 'n_estimators': 323, 'learning_rate': 0.2913761408555038, 'max_depth': 12, 'subsample': 0.8132914314628712, 'colsample_bytree': 0.9342847474320767}. Best is trial 128 with value: 0.7727272727272727.
# [I 2024-06-27 20:08:08,353] Trial 138 finished with value: 0.6666666666666666 and parameters: {'classifier': 'XGBoost', 'n_estimators': 315, 'learning_rate': 0.10823183079468231, 'max_depth': 11, 'subsample': 0.5881463724965919, 'colsample_bytree': 0.7532186712041474}. Best is trial 128 with value: 0.7727272727272727.
# [I 2024-06-27 20:08:08,829] Trial 144 finished with value: 0.6511627906976745 and parameters: {'classifier': 'XGBoost', 'n_estimators': 304, 'learning_rate': 0.11486778286628854, 'max_depth': 6, 'subsample': 0.7589727687137805, 'colsample_bytree': 0.9219055984706157}. Best is trial 128 with value: 0.7727272727272727.
# [I 2024-06-27 20:08:08,977] Trial 145 finished with value: 0.6222222222222222 and parameters: {'classifier': 'XGBoost', 'n_estimators': 299, 'learning_rate': 0.27601750463497704, 'max_depth': 6, 'subsample': 0.7464723353595601, 'colsample_bytree': 0.9389352121186817}. Best is trial 128 with value: 0.7727272727272727.
# [I 2024-06-27 20:08:09,348] Trial 149 finished with value: 0.6222222222222222 and parameters: {'classifier': 'XGBoost', 'n_estimators': 400, 'learning_rate': 0.1829981855036948, 'max_depth': 8, 'subsample': 0.6518931575369509, 'colsample_bytree': 0.9089581769165018}. Best is trial 128 with value: 0.7727272727272727.
# [I 2024-06-27 20:08:09,383] Trial 154 finished with value: 0.6046511627906976 and parameters: {'classifier': 'SVC', 'C': 10.12584629182776, 'kernel': 'sigmoid', 'gamma': 'auto'}. Best is trial 128 with value: 0.7727272727272727.
# [I 2024-06-27 20:08:09,517] Trial 150 finished with value: 0.625 and parameters: {'classifier': 'XGBoost', 'n_estimators': 391, 'learning_rate': 0.11457239305342788, 'max_depth': 8, 'subsample': 0.7473818580648055, 'colsample_bytree': 0.8630145524527474}. Best is trial 128 with value: 0.7727272727272727.
# [I 2024-06-27 20:08:09,534] Trial 148 finished with value: 0.6666666666666666 and parameters: {'classifier': 'XGBoost', 'n_estimators': 403, 'learning_rate': 0.11596326455385583, 'max_depth': 8, 'subsample': 0.7556209551303628, 'colsample_bytree': 0.8628364754842465}. Best is trial 128 with value: 0.7727272727272727.
# [I 2024-06-27 20:08:09,551] Trial 151 finished with value: 0.6363636363636364 and parameters: {'classifier': 'XGBoost', 'n_estimators': 408, 'learning_rate': 0.12265823087598379, 'max_depth': 8, 'subsample': 0.7576093530860514, 'colsample_bytree': 0.8613554840070439}. Best is trial 128 with value: 0.7727272727272727.
# [I 2024-06-27 20:08:09,588] Trial 147 finished with value: 0.7272727272727273 and parameters: {'classifier': 'XGBoost', 'n_estimators': 402, 'learning_rate': 0.11531577710064309, 'max_depth': 6, 'subsample': 0.7485234093756545, 'colsample_bytree': 0.8317622768084599}. Best is trial 128 with value: 0.7727272727272727.
# [I 2024-06-27 20:08:09,950] Trial 153 finished with value: 0.6666666666666666 and parameters: {'classifier': 'XGBoost', 'n_estimators': 418, 'learning_rate': 0.18374495328876905, 'max_depth': 8, 'subsample': 0.6570322657829207, 'colsample_bytree': 0.8301392551464853}. Best is trial 128 with value: 0.7727272727272727.
# [I 2024-06-27 20:08:10,066] Trial 146 finished with value: 0.6666666666666666 and parameters: {'classifier': 'XGBoost', 'n_estimators': 403, 'learning_rate': 0.019747644718183376, 'max_depth': 6, 'subsample': 0.7529945107083975, 'colsample_bytree': 0.9354443486367632}. Best is trial 128 with value: 0.7727272727272727.
# [I 2024-06-27 20:08:10,330] Trial 155 finished with value: 0.6818181818181818 and parameters: {'classifier': 'XGBoost', 'n_estimators': 404, 'learning_rate': 0.25839976143393506, 'max_depth': 15, 'subsample': 0.7437908757909406, 'colsample_bytree': 0.8301936287951774}. Best is trial 128 with value: 0.7727272727272727.
# [I 2024-06-27 20:08:10,462] Trial 152 finished with value: 0.6666666666666666 and parameters: {'classifier': 'XGBoost', 'n_estimators': 853, 'learning_rate': 0.1394146191130329, 'max_depth': 8, 'subsample': 0.7958350767588267, 'colsample_bytree': 0.8623790754462577}. Best is trial 128 with value: 0.7727272727272727.
# [I 2024-06-27 20:08:10,774] Trial 160 finished with value: 0.6666666666666666 and parameters: {'classifier': 'XGBoost', 'n_estimators': 457, 'learning_rate': 0.13785126993625135, 'max_depth': 5, 'subsample': 0.7928200834927803, 'colsample_bytree': 0.8822225838175404}. Best is trial 128 with value: 0.7727272727272727.
# [I 2024-06-27 20:08:11,006] Trial 157 finished with value: 0.6521739130434783 and parameters: {'classifier': 'XGBoost', 'n_estimators': 838, 'learning_rate': 0.17245497000590665, 'max_depth': 4, 'subsample': 0.7673957843850587, 'colsample_bytree': 0.8310312609422769}. Best is trial 128 with value: 0.7727272727272727.
# [I 2024-06-27 20:08:11,072] Trial 159 finished with value: 0.6818181818181818 and parameters: {'classifier': 'XGBoost', 'n_estimators': 849, 'learning_rate': 0.17386891162437412, 'max_depth': 7, 'subsample': 0.7924786448819241, 'colsample_bytree': 0.9994054576656166}. Best is trial 128 with value: 0.7727272727272727.
# ...
# [I 2024-06-27 20:15:22,859] Trial 1945 finished with value: 0.5652173913043478 and parameters: {'classifier': 'LightGBM', 'n_estimators': 367, 'learning_rate': 0.2271870824951426, 'max_depth': 29, 'num_leaves': 23, 'min_child_samples': 45}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:24,933] Trial 1944 finished with value: 0.65 and parameters: {'classifier': 'XGBoost', 'n_estimators': 367, 'learning_rate': 0.2141695551910627, 'max_depth': 29, 'subsample': 0.770757131925777, 'colsample_bytree': 0.9481828765630892}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:26,388] Trial 1948 finished with value: 0.6086956521739131 and parameters: {'classifier': 'RandomForest', 'n_estimators': 288, 'max_depth': 28, 'min_samples_split': 10, 'min_samples_leaf': 4}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:26,701] Trial 1949 finished with value: 0.6222222222222222 and parameters: {'classifier': 'RandomForest', 'n_estimators': 292, 'max_depth': 22, 'min_samples_split': 10, 'min_samples_leaf': 7}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:26,882] Trial 1950 finished with value: 0.5777777777777777 and parameters: {'classifier': 'XGBoost', 'n_estimators': 288, 'learning_rate': 0.20327146844744534, 'max_depth': 28, 'subsample': 0.7564171660630329, 'colsample_bytree': 0.9498437652441689}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:27,099] Trial 1953 finished with value: 0.6666666666666666 and parameters: {'classifier': 'RandomForest', 'n_estimators': 202, 'max_depth': 24, 'min_samples_split': 8, 'min_samples_leaf': 4}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:27,798] Trial 1954 finished with value: 0.5581395348837209 and parameters: {'classifier': 'XGBoost', 'n_estimators': 323, 'learning_rate': 0.22668982522831885, 'max_depth': 25, 'subsample': 0.757055234412515, 'colsample_bytree': 0.9775790055263506}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:27,916] Trial 1951 finished with value: 0.6222222222222222 and parameters: {'classifier': 'RandomForest', 'n_estimators': 296, 'max_depth': 28, 'min_samples_split': 10, 'min_samples_leaf': 7}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:28,473] Trial 1952 finished with value: 0.6382978723404256 and parameters: {'classifier': 'RandomForest', 'n_estimators': 326, 'max_depth': 27, 'min_samples_split': 10, 'min_samples_leaf': 4}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:28,624] Trial 1955 finished with value: 0.6521739130434783 and parameters: {'classifier': 'RandomForest', 'n_estimators': 206, 'max_depth': 25, 'min_samples_split': 10, 'min_samples_leaf': 4}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:28,710] Trial 1962 finished with value: 0.5483870967741935 and parameters: {'classifier': 'LogisticRegression', 'C': 0.0020432559283213025, 'solver': 'newton-cg'}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:29,214] Trial 1957 finished with value: 0.6086956521739131 and parameters: {'classifier': 'XGBoost', 'n_estimators': 199, 'learning_rate': 0.2490448722060772, 'max_depth': 11, 'subsample': 0.7577109495681198, 'colsample_bytree': 0.8017258461816749}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:29,409] Trial 1958 finished with value: 0.5853658536585366 and parameters: {'classifier': 'XGBoost', 'n_estimators': 202, 'learning_rate': 0.2395106871400897, 'max_depth': 20, 'subsample': 0.7591412379000702, 'colsample_bytree': 0.9774591376823112}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:29,714] Trial 1956 finished with value: 0.6511627906976745 and parameters: {'classifier': 'XGBoost', 'n_estimators': 330, 'learning_rate': 0.19205722301702038, 'max_depth': 23, 'subsample': 0.7904793915465603, 'colsample_bytree': 0.9755983734105624}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:29,816] Trial 1961 finished with value: 0.7272727272727273 and parameters: {'classifier': 'XGBoost', 'n_estimators': 207, 'learning_rate': 0.1952903271387404, 'max_depth': 26, 'subsample': 0.7891400365919443, 'colsample_bytree': 0.945847987163821}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:30,011] Trial 1963 finished with value: 0.7142857142857143 and parameters: {'classifier': 'XGBoost', 'n_estimators': 160, 'learning_rate': 0.21159928962024904, 'max_depth': 31, 'subsample': 0.7894266646932492, 'colsample_bytree': 0.780965450792728}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:30,014] Trial 1964 finished with value: 0.6829268292682927 and parameters: {'classifier': 'XGBoost', 'n_estimators': 166, 'learning_rate': 0.21464379060912445, 'max_depth': 25, 'subsample': 0.7704888515801536, 'colsample_bytree': 0.9437177348980577}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:30,049] Trial 1959 finished with value: 0.6808510638297872 and parameters: {'classifier': 'XGBoost', 'n_estimators': 323, 'learning_rate': 0.21460963974672134, 'max_depth': 25, 'subsample': 0.789509618235992, 'colsample_bytree': 0.9768522992768417}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:30,546] Trial 1960 finished with value: 0.6382978723404256 and parameters: {'classifier': 'XGBoost', 'n_estimators': 323, 'learning_rate': 0.20997109881581397, 'max_depth': 22, 'subsample': 0.788077006496037, 'colsample_bytree': 0.9453343916236809}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:31,077] Trial 1965 finished with value: 0.6976744186046512 and parameters: {'classifier': 'XGBoost', 'n_estimators': 163, 'learning_rate': 0.20765087270371935, 'max_depth': 28, 'subsample': 0.7898648932587726, 'colsample_bytree': 0.7799100703404405}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:31,426] Trial 1966 finished with value: 0.6363636363636364 and parameters: {'classifier': 'XGBoost', 'n_estimators': 162, 'learning_rate': 0.20923063729051486, 'max_depth': 25, 'subsample': 0.7890475928470572, 'colsample_bytree': 0.9999417289314774}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:31,801] Trial 1968 finished with value: 0.5116279069767442 and parameters: {'classifier': 'XGBoost', 'n_estimators': 163, 'learning_rate': 0.24244312653381977, 'max_depth': 20, 'subsample': 0.7704421622296699, 'colsample_bytree': 0.9311761508329628}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:31,907] Trial 1975 finished with value: 0.625 and parameters: {'classifier': 'SVC', 'C': 0.23902543844999916, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:32,160] Trial 1971 finished with value: 0.6190476190476191 and parameters: {'classifier': 'XGBoost', 'n_estimators': 247, 'learning_rate': 0.2300168546785601, 'max_depth': 11, 'subsample': 0.7755252471632207, 'colsample_bytree': 0.9315978314684985}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:32,253] Trial 1973 finished with value: 0.5909090909090909 and parameters: {'classifier': 'XGBoost', 'n_estimators': 243, 'learning_rate': 0.2700387010703641, 'max_depth': 24, 'subsample': 0.7682309026483481, 'colsample_bytree': 0.931131490513069}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:32,255] Trial 1970 finished with value: 0.7391304347826086 and parameters: {'classifier': 'XGBoost', 'n_estimators': 255, 'learning_rate': 0.20684072475509774, 'max_depth': 10, 'subsample': 0.7724213651026882, 'colsample_bytree': 0.9291564744289739}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:32,471] Trial 1972 finished with value: 0.6363636363636364 and parameters: {'classifier': 'XGBoost', 'n_estimators': 247, 'learning_rate': 0.20823458998921024, 'max_depth': 22, 'subsample': 0.8625377335314656, 'colsample_bytree': 0.9313012080464641}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:32,473] Trial 1969 finished with value: 0.6666666666666666 and parameters: {'classifier': 'XGBoost', 'n_estimators': 246, 'learning_rate': 0.1720536956443319, 'max_depth': 32, 'subsample': 0.9761319512458511, 'colsample_bytree': 0.9322152400088838}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:33,080] Trial 1974 finished with value: 0.6511627906976745 and parameters: {'classifier': 'XGBoost', 'n_estimators': 252, 'learning_rate': 0.23527512556952135, 'max_depth': 26, 'subsample': 0.771315447643242, 'colsample_bytree': 0.9334254339959657}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:33,817] Trial 1967 finished with value: 0.6666666666666666 and parameters: {'classifier': 'XGBoost', 'n_estimators': 620, 'learning_rate': 0.2607407886615228, 'max_depth': 11, 'subsample': 0.7700767039742027, 'colsample_bytree': 0.9400119778360007}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:34,152] Trial 1976 finished with value: 0.6829268292682927 and parameters: {'classifier': 'XGBoost', 'n_estimators': 256, 'learning_rate': 0.22956957991975144, 'max_depth': 18, 'subsample': 0.7677484176485608, 'colsample_bytree': 0.8946890158612352}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:34,467] Trial 1980 finished with value: 0.5777777777777777 and parameters: {'classifier': 'XGBoost', 'n_estimators': 191, 'learning_rate': 0.275499060393859, 'max_depth': 19, 'subsample': 0.7789510284068645, 'colsample_bytree': 0.8961301288191059}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:34,709] Trial 1977 finished with value: 0.65 and parameters: {'classifier': 'XGBoost', 'n_estimators': 248, 'learning_rate': 0.2321562245111267, 'max_depth': 25, 'subsample': 0.7709849795633176, 'colsample_bytree': 0.8995930118146053}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:34,802] Trial 1979 finished with value: 0.6818181818181818 and parameters: {'classifier': 'XGBoost', 'n_estimators': 267, 'learning_rate': 0.25508642856494784, 'max_depth': 24, 'subsample': 0.7790833833443953, 'colsample_bytree': 0.6106964578539079}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:35,008] Trial 1982 finished with value: 0.6363636363636364 and parameters: {'classifier': 'XGBoost', 'n_estimators': 282, 'learning_rate': 0.25676136573555386, 'max_depth': 21, 'subsample': 0.7774014935321021, 'colsample_bytree': 0.8905505222176339}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:35,022] Trial 1978 finished with value: 0.6666666666666666 and parameters: {'classifier': 'XGBoost', 'n_estimators': 267, 'learning_rate': 0.18896527388823547, 'max_depth': 25, 'subsample': 0.7784515521289642, 'colsample_bytree': 0.8969011568691169}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:35,294] Trial 1987 finished with value: 0.6153846153846154 and parameters: {'classifier': 'LogisticRegression', 'C': 29.218649596417894, 'solver': 'lbfgs'}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:35,357] Trial 1988 finished with value: 0.5666666666666667 and parameters: {'classifier': 'LogisticRegression', 'C': 0.0028424874879650042, 'solver': 'lbfgs'}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:35,579] Trial 1989 finished with value: 0.6153846153846154 and parameters: {'classifier': 'LogisticRegression', 'C': 27.940733931261295, 'solver': 'lbfgs'}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:35,991] Trial 1983 finished with value: 0.6818181818181818 and parameters: {'classifier': 'XGBoost', 'n_estimators': 272, 'learning_rate': 0.13457572848902588, 'max_depth': 31, 'subsample': 0.5639639902841914, 'colsample_bytree': 0.7627680306820099}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:36,391] Trial 1984 finished with value: 0.6976744186046512 and parameters: {'classifier': 'XGBoost', 'n_estimators': 278, 'learning_rate': 0.18677867342182097, 'max_depth': 9, 'subsample': 0.7818080911741591, 'colsample_bytree': 0.7682191128450999}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:36,823] Trial 1985 finished with value: 0.6956521739130435 and parameters: {'classifier': 'XGBoost', 'n_estimators': 279, 'learning_rate': 0.18926216128680368, 'max_depth': 21, 'subsample': 0.7991773475020627, 'colsample_bytree': 0.9143228738050052}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:36,951] Trial 1992 finished with value: 0.6666666666666666 and parameters: {'classifier': 'XGBoost', 'n_estimators': 74, 'learning_rate': 0.11730057110868691, 'max_depth': 24, 'subsample': 0.7976802141686422, 'colsample_bytree': 0.7651110265225097}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:37,335] Trial 1994 finished with value: 0.6976744186046512 and parameters: {'classifier': 'XGBoost', 'n_estimators': 83, 'learning_rate': 0.12510558592800008, 'max_depth': 20, 'subsample': 0.7989482313158208, 'colsample_bytree': 0.9855217308580078}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:37,500] Trial 1986 finished with value: 0.6521739130434783 and parameters: {'classifier': 'XGBoost', 'n_estimators': 279, 'learning_rate': 0.18714963687109615, 'max_depth': 26, 'subsample': 0.7987491694199614, 'colsample_bytree': 0.9150116232863312}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:37,652] Trial 1998 finished with value: 0.6376811594202898 and parameters: {'classifier': 'SVC', 'C': 0.0004309847770854459, 'kernel': 'poly', 'gamma': 'auto'}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:37,822] Trial 1991 finished with value: 0.7111111111111111 and parameters: {'classifier': 'XGBoost', 'n_estimators': 219, 'learning_rate': 0.12517487365310653, 'max_depth': 22, 'subsample': 0.7284658160734638, 'colsample_bytree': 0.7654156129964783}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:37,940] Trial 1981 finished with value: 0.6222222222222222 and parameters: {'classifier': 'XGBoost', 'n_estimators': 909, 'learning_rate': 0.13516730059277787, 'max_depth': 20, 'subsample': 0.7788069916857102, 'colsample_bytree': 0.5519255857897847}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:38,009] Trial 1993 finished with value: 0.6511627906976745 and parameters: {'classifier': 'XGBoost', 'n_estimators': 218, 'learning_rate': 0.11615576237873175, 'max_depth': 22, 'subsample': 0.7980277966796268, 'colsample_bytree': 0.9129430989264176}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:38,162] Trial 1995 finished with value: 0.6341463414634146 and parameters: {'classifier': 'XGBoost', 'n_estimators': 219, 'learning_rate': 0.11658295674633856, 'max_depth': 9, 'subsample': 0.757292866141674, 'colsample_bytree': 0.9860572802429488}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:38,387] Trial 1990 finished with value: 0.7083333333333334 and parameters: {'classifier': 'XGBoost', 'n_estimators': 909, 'learning_rate': 0.12411388414466017, 'max_depth': 30, 'subsample': 0.7259174701941167, 'colsample_bytree': 0.761190446941298}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:38,517] Trial 1996 finished with value: 0.6976744186046512 and parameters: {'classifier': 'XGBoost', 'n_estimators': 899, 'learning_rate': 0.1757378091122744, 'max_depth': 10, 'subsample': 0.7249267404655251, 'colsample_bytree': 0.7448673195607705}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:38,611] Trial 1999 finished with value: 0.6521739130434783 and parameters: {'classifier': 'XGBoost', 'n_estimators': 916, 'learning_rate': 0.1613812548401179, 'max_depth': 29, 'subsample': 0.7559850067648346, 'colsample_bytree': 0.9487278907674671}. Best is trial 756 with value: 0.8.
# [I 2024-06-27 20:15:38,613] Trial 1997 finished with value: 0.6818181818181818 and parameters: {'classifier': 'XGBoost', 'n_estimators': 901, 'learning_rate': 0.11316885422563652, 'max_depth': 24, 'subsample': 0.7579513103925801, 'colsample_bytree': 0.9136502651678333}. Best is trial 756 with value: 0.8.
# Best trial: 0.8
# Best params: {'classifier': 'XGBoost', 'n_estimators': 894, 'learning_rate': 0.29345153265292323, 'max_depth': 8, 'subsample': 0.6860346003798784, 'colsample_bytree': 0.8902776358145003}
# Validation f1_score with the best model: 0.8

# %%
file_path = r'.\crawling_data\preprocessed_essay.csv'

# 자소서 리스트화
documents = []
with open(file_path, 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        documents.append(row[0])

# 사용하지 않은 2점짜리 자소서 리스트
documents = documents[-175:-77]

# %%
# 불용어 리스트 가져오기
stop_words = set(stopwords.words('english'))

def preprocess(text):
    tokens = word_tokenize(text)
    filtered_tokens = [word for word in tokens if word.isalpha() and word not in stop_words]
    return filtered_tokens

documents_corpus = []
for document in documents:
    documents_corpus.append(preprocess(document))

# %%
best_params = {'vector_size': 99, 'window': 3, 'min_count': 1, 'epochs': 10}

best_vector_size = best_params['vector_size']
best_window = best_params['window']
best_min_count = best_params['min_count']
best_epochs = best_params['epochs']

best_d2vmodel = Doc2Vec(vector_size=best_vector_size, window=best_window, min_count=best_min_count, epochs=best_epochs)
best_d2vmodel.build_vocab(my_tagged_corpus)
best_d2vmodel.train(my_tagged_corpus, total_examples=best_d2vmodel.corpus_count, epochs=best_d2vmodel.epochs)
d2v_vec = [best_d2vmodel.infer_vector(doc) for doc in documents_corpus]

# %%
print(1-best_model.predict(d2v_vec).mean())
# Out:
# 0.7244897959183674

# %%
import pickle

with open('d2v_model.pkl', 'wb') as f:
    pickle.dump(best_d2vmodel, f)

with open('clf_model.pkl', 'wb') as f:
    pickle.dump(best_model, f)
