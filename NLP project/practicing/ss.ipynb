# %%
import pandas as pd
import numpy as np
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.combine import SMOTETomek
import optuna
import csv

# Load and preprocess data (as before)
file_path = r'.\crawling_data\preprocessed_essay.csv'

# 자소서 리스트화
documents = []
with open(file_path, 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        documents.append(row[0])

# 전문가 평점 1~5점 각 15개씩 랜덤으로 가져와서 점수 라벨링
# 회귀 예측용 label
labels = []
for i in range(317):
    if i < 22:
        labels.append(5)
    elif i < 77:
        labels.append(4)
    elif i < 175:
        labels.append(3)
    elif i < 302:
        labels.append(2)        
    else:
        labels.append(1)

# Preprocess the essays
from nltk.tokenize import word_tokenize

def preprocess(text):
    return word_tokenize(text.lower())

# Create tagged documents
tagged_data = [TaggedDocument(words=preprocess(essay), tags=[str(i)]) for i, essay in enumerate(documents)]

# Split the data
X_train, X_test, y_train, y_test = train_test_split(tagged_data, labels, test_size=0.2, random_state=42)

# Modified build_doc2vec_model function (as before)
from gensim.models.doc2vec import Doc2Vec

def build_doc2vec_model(vector_size, window, min_count, epochs):
    model = Doc2Vec(vector_size=vector_size,
                    window=window,
                    min_count=min_count,
                    dm=1,  # Use PV-DM
                    epochs=epochs,
                    workers=4)
    
    model.build_vocab(tagged_data)
    model.train(tagged_data, total_examples=model.corpus_count, epochs=model.epochs)
    
    return model


def train_and_evaluate(doc2vec_model, X_train, X_test, y_train, y_test, resampling=None, rf_params=None):
    # Generate document vectors
    X_train_vecs = np.array([doc2vec_model.infer_vector(doc.words) for doc in X_train])
    X_test_vecs = np.array([doc2vec_model.infer_vector(doc.words) for doc in X_test])
    
    # Apply resampling if specified
    if resampling == 'smote':
        smote = SMOTE(random_state=42)
        X_train_vecs, y_train = smote.fit_resample(X_train_vecs, y_train)
    elif resampling == 'undersampling':
        rus = RandomUnderSampler(random_state=42)
        X_train_vecs, y_train = rus.fit_resample(X_train_vecs, y_train)
    elif resampling == 'smotetomek':
        smt = SMOTETomek(random_state=42)
        X_train_vecs, y_train = smt.fit_resample(X_train_vecs, y_train)
    
    # Train Random Forest Regressor with hyperparameters
    rf = RandomForestRegressor(**rf_params, random_state=42)
    rf.fit(X_train_vecs, y_train)
    
    # Make predictions
    y_pred = rf.predict(X_test_vecs)
    
    # Evaluate
    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    return np.sqrt(mse), mae, r2

def objective(trial):
    # Define hyperparameters to optimize for Doc2Vec
    vector_size = trial.suggest_int('vector_size', 20, 50)
    window = trial.suggest_int('window', 3, 15)
    min_count = trial.suggest_int('min_count', 1, 10)
    epochs = trial.suggest_int('epochs', 10, 50, step=5)
    
    # Define hyperparameters to optimize for RandomForestRegressor
    n_estimators = trial.suggest_int('n_estimators', 30, 500, step=10)
    max_depth = trial.suggest_int('max_depth', 5, 30)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 4)
    
    # Choose resampling method
    resampling = trial.suggest_categorical('resampling', ['none', 'smote', 'undersampling', 'smotetomek'])
    
    # Build and train Doc2Vec model
    model = build_doc2vec_model(vector_size, window, min_count, epochs)
    
    # Evaluate the model
    rf_params = {
        'n_estimators': n_estimators,
        'max_depth': max_depth,
        'min_samples_split': min_samples_split,
        'min_samples_leaf': min_samples_leaf
    }
    rmse, mae, r2 = train_and_evaluate(model, X_train, X_test, y_train, y_test, resampling, rf_params)
    
    # We'll use MAE as our optimization metric, but you can change this based on your needs
    return r2

# Run optimization
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=200, n_jobs=-1)

print('Best trial:')
trial = study.best_trial
print(f'  r2: {trial.value}')
print('  Params: ')
for key, value in trial.params.items():
    print(f'    {key}: {value}')

# Train final model with best parameters
best_params = study.best_params
final_model = build_doc2vec_model(
    vector_size=best_params['vector_size'],
    window=best_params['window'],
    min_count=best_params['min_count'],
    epochs=best_params['epochs']
)

# Train and evaluate the final model
final_rf_params = {
    'n_estimators': best_params['n_estimators'],
    'max_depth': best_params['max_depth'],
    'min_samples_split': best_params['min_samples_split'],
    'min_samples_leaf': best_params['min_samples_leaf']
}

resampling_method = best_params['resampling'] if best_params['resampling'] != 'none' else None

# Evaluate the final model
rmse, mae, r2 = train_and_evaluate(final_model, X_train, X_test, y_train, y_test, resampling_method, final_rf_params)

print(f'Final Model Performance:')
print(f'  RMSE: {rmse}')
print(f'  MAE: {mae}')
print(f'  R2: {r2}')
# Out:
# [I 2024-06-27 15:32:08,451] A new study created in memory with name: no-name-c3d8853d-c82f-439a-9730-89268c1d3fdd
# [I 2024-06-27 15:32:57,174] Trial 3 finished with value: 0.028576058695159445 and parameters: {'vector_size': 48, 'window': 4, 'min_count': 9, 'epochs': 30, 'n_estimators': 220, 'max_depth': 20, 'min_samples_split': 8, 'min_samples_leaf': 1, 'resampling': 'smotetomek'}. Best is trial 3 with value: 0.028576058695159445.
# [I 2024-06-27 15:33:03,378] Trial 1 finished with value: -0.11215228261664234 and parameters: {'vector_size': 48, 'window': 8, 'min_count': 3, 'epochs': 30, 'n_estimators': 450, 'max_depth': 18, 'min_samples_split': 9, 'min_samples_leaf': 3, 'resampling': 'smote'}. Best is trial 3 with value: 0.028576058695159445.
# [I 2024-06-27 15:33:07,663] Trial 2 finished with value: 0.16243969566111272 and parameters: {'vector_size': 30, 'window': 12, 'min_count': 1, 'epochs': 30, 'n_estimators': 30, 'max_depth': 21, 'min_samples_split': 7, 'min_samples_leaf': 2, 'resampling': 'none'}. Best is trial 2 with value: 0.16243969566111272.
# [I 2024-06-27 15:33:10,486] Trial 5 finished with value: -0.3675466610982039 and parameters: {'vector_size': 25, 'window': 10, 'min_count': 3, 'epochs': 30, 'n_estimators': 420, 'max_depth': 20, 'min_samples_split': 10, 'min_samples_leaf': 2, 'resampling': 'smote'}. Best is trial 2 with value: 0.16243969566111272.
# [I 2024-06-27 15:33:14,999] Trial 0 finished with value: 0.07110471398373164 and parameters: {'vector_size': 47, 'window': 15, 'min_count': 1, 'epochs': 35, 'n_estimators': 270, 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 2, 'resampling': 'smote'}. Best is trial 2 with value: 0.16243969566111272.
# [I 2024-06-27 15:33:24,090] Trial 4 finished with value: 0.16204609085936905 and parameters: {'vector_size': 45, 'window': 5, 'min_count': 10, 'epochs': 40, 'n_estimators': 110, 'max_depth': 22, 'min_samples_split': 4, 'min_samples_leaf': 3, 'resampling': 'none'}. Best is trial 2 with value: 0.16243969566111272.
# [I 2024-06-27 15:33:26,427] Trial 8 finished with value: -0.408104189266848 and parameters: {'vector_size': 21, 'window': 6, 'min_count': 10, 'epochs': 15, 'n_estimators': 110, 'max_depth': 28, 'min_samples_split': 10, 'min_samples_leaf': 2, 'resampling': 'smotetomek'}. Best is trial 2 with value: 0.16243969566111272.
# [I 2024-06-27 15:33:31,069] Trial 7 finished with value: -0.014063057511525257 and parameters: {'vector_size': 41, 'window': 3, 'min_count': 7, 'epochs': 45, 'n_estimators': 290, 'max_depth': 25, 'min_samples_split': 5, 'min_samples_leaf': 1, 'resampling': 'undersampling'}. Best is trial 2 with value: 0.16243969566111272.
# [I 2024-06-27 15:33:32,874] Trial 6 finished with value: 0.09981532717711639 and parameters: {'vector_size': 24, 'window': 3, 'min_count': 3, 'epochs': 45, 'n_estimators': 130, 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 2, 'resampling': 'none'}. Best is trial 2 with value: 0.16243969566111272.
# [I 2024-06-27 15:33:49,474] Trial 11 finished with value: 0.07361679656151887 and parameters: {'vector_size': 28, 'window': 5, 'min_count': 5, 'epochs': 20, 'n_estimators': 30, 'max_depth': 21, 'min_samples_split': 6, 'min_samples_leaf': 2, 'resampling': 'undersampling'}. Best is trial 2 with value: 0.16243969566111272.
# [I 2024-06-27 15:34:04,640] Trial 10 finished with value: 0.17585642653698053 and parameters: {'vector_size': 43, 'window': 12, 'min_count': 10, 'epochs': 30, 'n_estimators': 420, 'max_depth': 16, 'min_samples_split': 9, 'min_samples_leaf': 4, 'resampling': 'undersampling'}. Best is trial 10 with value: 0.17585642653698053.
# [I 2024-06-27 15:34:11,331] Trial 12 finished with value: 0.0956847749953551 and parameters: {'vector_size': 24, 'window': 13, 'min_count': 5, 'epochs': 30, 'n_estimators': 70, 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 4, 'resampling': 'none'}. Best is trial 10 with value: 0.17585642653698053.
# [I 2024-06-27 15:34:19,146] Trial 9 finished with value: 0.039132171124854676 and parameters: {'vector_size': 37, 'window': 4, 'min_count': 5, 'epochs': 45, 'n_estimators': 280, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 3, 'resampling': 'smote'}. Best is trial 10 with value: 0.17585642653698053.
# [I 2024-06-27 15:34:26,550] Trial 15 finished with value: 0.1046318071664657 and parameters: {'vector_size': 36, 'window': 13, 'min_count': 7, 'epochs': 30, 'n_estimators': 200, 'max_depth': 11, 'min_samples_split': 2, 'min_samples_leaf': 3, 'resampling': 'smote'}. Best is trial 10 with value: 0.17585642653698053.
# [I 2024-06-27 15:34:27,642] Trial 13 finished with value: -0.02913749202949001 and parameters: {'vector_size': 21, 'window': 3, 'min_count': 5, 'epochs': 35, 'n_estimators': 80, 'max_depth': 19, 'min_samples_split': 9, 'min_samples_leaf': 4, 'resampling': 'undersampling'}. Best is trial 10 with value: 0.17585642653698053.
# [I 2024-06-27 15:34:28,281] Trial 17 finished with value: 0.11761288064027886 and parameters: {'vector_size': 34, 'window': 13, 'min_count': 1, 'epochs': 20, 'n_estimators': 30, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 4, 'resampling': 'none'}. Best is trial 10 with value: 0.17585642653698053.
# [I 2024-06-27 15:34:35,252] Trial 16 finished with value: 0.1199075415298948 and parameters: {'vector_size': 27, 'window': 14, 'min_count': 8, 'epochs': 35, 'n_estimators': 30, 'max_depth': 22, 'min_samples_split': 5, 'min_samples_leaf': 4, 'resampling': 'none'}. Best is trial 10 with value: 0.17585642653698053.
# [I 2024-06-27 15:34:44,497] Trial 18 finished with value: 0.14980307345147226 and parameters: {'vector_size': 34, 'window': 13, 'min_count': 7, 'epochs': 20, 'n_estimators': 370, 'max_depth': 13, 'min_samples_split': 8, 'min_samples_leaf': 4, 'resampling': 'none'}. Best is trial 10 with value: 0.17585642653698053.
# [I 2024-06-27 15:34:45,327] Trial 14 finished with value: 0.017850122677882996 and parameters: {'vector_size': 23, 'window': 9, 'min_count': 5, 'epochs': 40, 'n_estimators': 150, 'max_depth': 22, 'min_samples_split': 2, 'min_samples_leaf': 1, 'resampling': 'smotetomek'}. Best is trial 10 with value: 0.17585642653698053.
# [I 2024-06-27 15:34:50,982] Trial 19 finished with value: 0.07310481350016718 and parameters: {'vector_size': 34, 'window': 11, 'min_count': 7, 'epochs': 20, 'n_estimators': 370, 'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 4, 'resampling': 'undersampling'}. Best is trial 10 with value: 0.17585642653698053.
# [I 2024-06-27 15:34:58,791] Trial 20 finished with value: 0.08264826542971615 and parameters: {'vector_size': 32, 'window': 11, 'min_count': 7, 'epochs': 20, 'n_estimators': 370, 'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 4, 'resampling': 'undersampling'}. Best is trial 10 with value: 0.17585642653698053.
# [I 2024-06-27 15:35:07,014] Trial 22 finished with value: 0.13463689046204574 and parameters: {'vector_size': 32, 'window': 11, 'min_count': 1, 'epochs': 20, 'n_estimators': 370, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 4, 'resampling': 'undersampling'}. Best is trial 10 with value: 0.17585642653698053.
# [I 2024-06-27 15:35:09,056] Trial 21 finished with value: 0.015256630167420515 and parameters: {'vector_size': 32, 'window': 11, 'min_count': 1, 'epochs': 20, 'n_estimators': 360, 'max_depth': 15, 'min_samples_split': 8, 'min_samples_leaf': 4, 'resampling': 'undersampling'}. Best is trial 10 with value: 0.17585642653698053.
# [I 2024-06-27 15:35:09,577] Trial 25 finished with value: -0.0809331647717455 and parameters: {'vector_size': 31, 'window': 11, 'min_count': 3, 'epochs': 10, 'n_estimators': 490, 'max_depth': 16, 'min_samples_split': 7, 'min_samples_leaf': 1, 'resampling': 'undersampling'}. Best is trial 10 with value: 0.17585642653698053.
# [I 2024-06-27 15:35:10,247] Trial 26 finished with value: 0.001462839009450767 and parameters: {'vector_size': 31, 'window': 11, 'min_count': 2, 'epochs': 10, 'n_estimators': 490, 'max_depth': 16, 'min_samples_split': 7, 'min_samples_leaf': 3, 'resampling': 'undersampling'}. Best is trial 10 with value: 0.17585642653698053.
# [I 2024-06-27 15:35:10,562] Trial 23 finished with value: 0.026435037924631644 and parameters: {'vector_size': 32, 'window': 10, 'min_count': 8, 'epochs': 20, 'n_estimators': 390, 'max_depth': 15, 'min_samples_split': 7, 'min_samples_leaf': 1, 'resampling': 'undersampling'}. Best is trial 10 with value: 0.17585642653698053.
# [I 2024-06-27 15:35:15,483] Trial 27 finished with value: 0.03342352911034474 and parameters: {'vector_size': 30, 'window': 11, 'min_count': 2, 'epochs': 10, 'n_estimators': 480, 'max_depth': 16, 'min_samples_split': 7, 'min_samples_leaf': 3, 'resampling': 'undersampling'}. Best is trial 10 with value: 0.17585642653698053.
# [I 2024-06-27 15:35:20,332] Trial 24 finished with value: -0.004045223757403349 and parameters: {'vector_size': 31, 'window': 11, 'min_count': 7, 'epochs': 20, 'n_estimators': 390, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 1, 'resampling': 'undersampling'}. Best is trial 10 with value: 0.17585642653698053.
# [I 2024-06-27 15:36:30,078] Trial 28 finished with value: 0.16979781428243335 and parameters: {'vector_size': 43, 'window': 7, 'min_count': 10, 'epochs': 50, 'n_estimators': 200, 'max_depth': 24, 'min_samples_split': 4, 'min_samples_leaf': 3, 'resampling': 'none'}. Best is trial 10 with value: 0.17585642653698053.
# [I 2024-06-27 15:36:34,717] Trial 29 finished with value: 0.18898017148959334 and parameters: {'vector_size': 44, 'window': 7, 'min_count': 10, 'epochs': 50, 'n_estimators': 500, 'max_depth': 25, 'min_samples_split': 4, 'min_samples_leaf': 3, 'resampling': 'none'}. Best is trial 29 with value: 0.18898017148959334.
# [I 2024-06-27 15:36:37,814] Trial 32 finished with value: 0.15318439312282228 and parameters: {'vector_size': 43, 'window': 7, 'min_count': 10, 'epochs': 50, 'n_estimators': 180, 'max_depth': 25, 'min_samples_split': 4, 'min_samples_leaf': 3, 'resampling': 'none'}. Best is trial 29 with value: 0.18898017148959334.
# [I 2024-06-27 15:36:38,572] Trial 31 finished with value: 0.127177726970088 and parameters: {'vector_size': 42, 'window': 7, 'min_count': 10, 'epochs': 50, 'n_estimators': 180, 'max_depth': 25, 'min_samples_split': 4, 'min_samples_leaf': 3, 'resampling': 'none'}. Best is trial 29 with value: 0.18898017148959334.
# [I 2024-06-27 15:36:39,862] Trial 30 finished with value: 0.11022021244267932 and parameters: {'vector_size': 43, 'window': 7, 'min_count': 10, 'epochs': 50, 'n_estimators': 480, 'max_depth': 25, 'min_samples_split': 4, 'min_samples_leaf': 3, 'resampling': 'none'}. Best is trial 29 with value: 0.18898017148959334.
# [I 2024-06-27 15:36:41,645] Trial 33 finished with value: 0.1934196300048533 and parameters: {'vector_size': 44, 'window': 7, 'min_count': 10, 'epochs': 50, 'n_estimators': 180, 'max_depth': 25, 'min_samples_split': 4, 'min_samples_leaf': 3, 'resampling': 'none'}. Best is trial 33 with value: 0.1934196300048533.
# [I 2024-06-27 15:36:43,363] Trial 34 finished with value: 0.13486369762487216 and parameters: {'vector_size': 43, 'window': 7, 'min_count': 10, 'epochs': 50, 'n_estimators': 180, 'max_depth': 24, 'min_samples_split': 4, 'min_samples_leaf': 3, 'resampling': 'none'}. Best is trial 33 with value: 0.1934196300048533.
# [I 2024-06-27 15:36:51,475] Trial 35 finished with value: 0.2295184570405886 and parameters: {'vector_size': 43, 'window': 7, 'min_count': 10, 'epochs': 50, 'n_estimators': 320, 'max_depth': 25, 'min_samples_split': 4, 'min_samples_leaf': 3, 'resampling': 'none'}. Best is trial 35 with value: 0.2295184570405886.
# [I 2024-06-27 15:37:20,952] Trial 40 finished with value: 0.17541106666647643 and parameters: {'vector_size': 50, 'window': 8, 'min_count': 9, 'epochs': 25, 'n_estimators': 240, 'max_depth': 28, 'min_samples_split': 3, 'min_samples_leaf': 2, 'resampling': 'none'}. Best is trial
 'max_depth': 8, 'min_samples_split': 4, 'min_samples_leaf': 2, 'resampling': 'smotetomek'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:46:24,944] Trial 98 finished with value: 0.17337994803571577 and parameters: {'vector_size': 49, 'window': 15, 'min_count': 10, 'epochs': 30, 'n_estimators': 440, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 2, 'resampling': 'none'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:46:29,593] Trial 99 finished with value: 0.21650858675617812 and parameters: {'vector_size': 40, 'window': 14, 'min_count': 10, 'epochs': 30, 'n_estimators': 330, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 2, 'resampling': 'smotetomek'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:46:31,837] Trial 100 finished with value: 0.024808054125125656 and parameters: {'vector_size': 40, 'window': 14, 'min_count': 10, 'epochs': 30, 'n_estimators': 370, 'max_depth': 8, 'min_samples_split': 4, 'min_samples_leaf': 2, 'resampling': 'smotetomek'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:46:36,844] Trial 101 finished with value: -0.0017112518497801599 and parameters: {'vector_size': 40, 'window': 14, 'min_count': 10, 'epochs': 30, 'n_estimators': 370, 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 2, 'resampling': 'smotetomek'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:46:43,741] Trial 102 finished with value: 0.1521564777337613 and parameters: {'vector_size': 40, 'window': 14, 'min_count': 10, 'epochs': 30, 'n_estimators': 430, 'max_depth': 24, 'min_samples_split': 5, 'min_samples_leaf': 2, 'resampling': 'smotetomek'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:47:02,035] Trial 103 finished with value: 0.08490671827692298 and parameters: {'vector_size': 40, 'window': 14, 'min_count': 10, 'epochs': 30, 'n_estimators': 470, 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 2, 'resampling': 'smote'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:47:12,513] Trial 104 finished with value: 0.13432759462110966 and parameters: {'vector_size': 40, 'window': 14, 'min_count': 10, 'epochs': 35, 'n_estimators': 370, 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 2, 'resampling': 'smote'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:47:23,331] Trial 105 finished with value: 0.004013855162037783 and parameters: {'vector_size': 40, 'window': 14, 'min_count': 9, 'epochs': 35, 'n_estimators': 370, 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 2, 'resampling': 'smote'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:47:31,769] Trial 106 finished with value: -0.12058417063009208 and parameters: {'vector_size': 40, 'window': 14, 'min_count': 9, 'epochs': 35, 'n_estimators': 370, 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 2, 'resampling': 'smote'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:47:35,393] Trial 107 finished with value: -0.034364095138502915 and parameters: {'vector_size': 38, 'window': 14, 'min_count': 9, 'epochs': 35, 'n_estimators': 270, 'max_depth': 24, 'min_samples_split': 5, 'min_samples_leaf': 2, 'resampling': 'smote'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:47:36,035] Trial 108 finished with value: 0.08434302795672755 and parameters: {'vector_size': 43, 'window': 14, 'min_count': 9, 'epochs': 35, 'n_estimators': 270, 'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 2, 'resampling': 'none'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:47:45,274] Trial 109 finished with value: 0.18946450131250558 and parameters: {'vector_size': 43, 'window': 6, 'min_count': 9, 'epochs': 35, 'n_estimators': 470, 'max_depth': 24, 'min_samples_split': 5, 'min_samples_leaf': 2, 'resampling': 'none'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:47:53,857] Trial 110 finished with value: 0.21792038684149595 and parameters: {'vector_size': 43, 'window': 10, 'min_count': 9, 'epochs': 35, 'n_estimators': 270, 'max_depth': 25, 'min_samples_split': 3, 'min_samples_leaf': 2, 'resampling': 'none'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:47:58,204] Trial 112 finished with value: 0.2196011866298896 and parameters: {'vector_size': 43, 'window': 15, 'min_count': 9, 'epochs': 25, 'n_estimators': 270, 'max_depth': 24, 'min_samples_split': 3, 'min_samples_leaf': 2, 'resampling': 'none'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:48:11,928] Trial 111 finished with value: 0.11181147065404795 and parameters: {'vector_size': 43, 'window': 10, 'min_count': 9, 'epochs': 35, 'n_estimators': 270, 'max_depth': 24, 'min_samples_split': 3, 'min_samples_leaf': 2, 'resampling': 'none'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:48:14,121] Trial 113 finished with value: 0.13551585487692375 and parameters: {'vector_size': 43, 'window': 10, 'min_count': 9, 'epochs': 25, 'n_estimators': 270, 'max_depth': 24, 'min_samples_split': 3, 'min_samples_leaf': 2, 'resampling': 'none'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:48:22,890] Trial 114 finished with value: 0.2073693718789379 and parameters: {'vector_size': 43, 'window': 10, 'min_count': 9, 'epochs': 25, 'n_estimators': 270, 'max_depth': 25, 'min_samples_split': 3, 'min_samples_leaf': 2, 'resampling': 'none'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:48:26,976] Trial 115 finished with value: 0.1901846364461025 and parameters: {'vector_size': 43, 'window': 10, 'min_count': 9, 'epochs': 25, 'n_estimators': 310, 'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 2, 'resampling': 'none'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:48:28,124] Trial 116 finished with value: 0.09545462475147204 and parameters: {'vector_size': 43, 'window': 10, 'min_count': 3, 'epochs': 25, 'n_estimators': 290, 'max_depth': 25, 'min_samples_split': 3, 'min_samples_leaf': 2, 'resampling': 'none'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:48:31,404] Trial 117 finished with value: 0.15571469902416546 and parameters: {'vector_size': 43, 'window': 15, 'min_count': 10, 'epochs': 25, 'n_estimators': 290, 'max_depth': 25, 'min_samples_split': 3, 'min_samples_leaf': 3, 'resampling': 'none'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:48:47,033] Trial 118 finished with value: 0.20957376292356222 and parameters: {'vector_size': 43, 'window': 10, 'min_count': 10, 'epochs': 25, 'n_estimators': 290, 'max_depth': 25, 'min_samples_split': 3, 'min_samples_leaf': 2, 'resampling': 'none'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:48:51,817] Trial 119 finished with value: 0.14801307481192705 and parameters: {'vector_size': 43, 'window': 10, 'min_count': 9, 'epochs': 25, 'n_estimators': 290, 'max_depth': 25, 'min_samples_split': 3, 'min_samples_leaf': 2, 'resampling': 'none'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:49:01,202] Trial 121 finished with value: -0.015897151155470413 and parameters: {'vector_size': 35, 'window': 4, 'min_count': 3, 'epochs': 25, 'n_estimators': 290, 'max_depth': 25, 'min_samples_split': 3, 'min_samples_leaf': 2, 'resampling': 'none'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:49:01,465] Trial 120 finished with value: 0.18368137279716745 and parameters: {'vector_size': 42, 'window': 15, 'min_count': 9, 'epochs': 25, 'n_estimators': 310, 'max_depth': 25, 'min_samples_split': 3, 'min_samples_leaf': 2, 'resampling': 'none'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:49:10,935] Trial 122 finished with value: -0.0968291158860981 and parameters: {'vector_size': 42, 'window': 4, 'min_count': 3, 'epochs': 25, 'n_estimators': 290, 'max_depth': 25, 'min_samples_split': 3, 'min_samples_leaf': 2, 'resampling': 'undersampling'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:49:15,146] Trial 123 finished with value: 0.016328686632074874 and parameters: {'vector_size': 20, 'window': 4, 'min_count': 3, 'epochs': 25, 'n_estimators': 290, 'max_depth': 21, 'min_samples_split': 3, 'min_samples_leaf': 2, 'resampling': 'undersampling'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:49:16,378] Trial 125 finished with value: -0.12344513651058597 and parameters: {'vector_size': 45, 'window': 6, 'min_count': 8, 'epochs': 20, 'n_estimators': 250, 'max_depth': 22, 'min_samples_split': 4, 'min_samples_leaf': 2, 'resampling': 'undersampling'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:49:20,384] Trial 124 finished with value: 0.1273560649377039 and parameters: {'vector_size': 45, 'window': 15, 'min_count': 5, 'epochs': 25, 'n_estimators': 250, 'max_depth': 22, 'min_samples_split': 3, 'min_samples_leaf': 3, 'resampling': 'undersampling'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:49:27,647] Trial 126 finished with value: 0.0032364417861328043 and parameters: {'vector_size': 20, 'window': 4, 'min_count': 8, 'epochs': 20, 'n_estimators': 310, 'max_depth': 28, 'min_samples_split': 4, 'min_samples_leaf': 2, 'resampling': 'undersampling'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:49:36,599] Trial 127 finished with value: -0.05737963728057549 and parameters: {'vector_size': 35, 'window': 3, 'min_count': 5, 'epochs': 20, 'n_estimators': 250, 'max_depth': 22, 'min_samples_split': 4, 'min_samples_leaf': 2, 'resampling': 'undersampling'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:49:42,076] Trial 129 finished with value: 0.13907518607540625 and parameters: {'vector_size': 42, 'window': 15, 'min_count': 10, 'epochs': 20, 'n_estimators': 330, 'max_depth': 22, 'min_samples_split': 4, 'min_samples_leaf': 2, 'resampling': 'undersampling'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:49:42,913] Trial 128 finished with value: 0.14481661181941097 and parameters: {'vector_size': 45, 'window': 15, 'min_count': 10, 'epochs': 20, 'n_estimators': 310, 'max_depth': 28, 'min_samples_split': 4, 'min_samples_leaf': 2, 'resampling': 'undersampling'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:50:10,186] Trial 130 finished with value: 0.11889068515001755 and parameters: {'vector_size': 45, 'window': 15, 'min_count': 10, 'epochs': 30, 'n_estimators': 250, 'max_depth': 28, 'min_samples_split': 4, 'min_samples_leaf': 2, 'resampling': 'none'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:50:13,354] Trial 131 finished with value: 0.2388021992986551 and parameters: {'vector_size': 45, 'window': 15, 'min_count': 10, 'epochs': 30, 'n_estimators': 250, 'max_depth': 28, 'min_samples_split': 4, 'min_samples_leaf': 2, 'resampling': 'none'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:50:13,929] Trial 132 finished with value: 0.21954060048068813 and parameters: {'vector_size': 44, 'window': 15, 'min_count': 10, 'epochs': 30, 'n_estimators': 330, 'max_depth': 27, 'min_samples_split': 4, 'min_samples_leaf': 2, 'resampling': 'none'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:50:17,490] Trial 133 finished with value: 0.19346570839433797 and parameters: {'vector_size': 44, 'window': 15, 'min_count': 10, 'epochs': 30, 'n_estimators': 330, 'max_depth': 28, 'min_samples_split': 10, 'min_samples_leaf': 2, 'resampling': 'none'}. Best is trial 80 with value: 0.25763910015346503.
# [I 2024-06-27 15:50:23,226] Trial 134 finished with value: 0.16534414409772558 and parameters: {'vector_size': 44, 'window': 15, 'min_count': 10, 'epochs': 30, 'n_estimators': 200, 'max_depth': 27, 'min_samples_split': 10, 'min_samples_leaf': 2, 'resampling': 'none'}. Best is trial 80 with value: 0.25763910015346503.
